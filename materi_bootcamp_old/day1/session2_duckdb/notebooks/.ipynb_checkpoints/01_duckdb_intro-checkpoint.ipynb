# %% [markdown]
# # 🦆 Sesi 2: DuckDB untuk Query Analitik
#
# Notebook ini mengikuti materi pada `slides/02_session2_duckdb.md` sehingga setiap konsep di kelas bisa langsung dicoba.
#
# **Fokus utama:** memahami konsep OLAP ala DuckDB, menulis SQL analitik (aggregations, window functions, CTE), dan mengintegrasikannya dengan alur kerja Pandas.

# %% [markdown]
# ## 🎯 Tujuan Pembelajaran
#
# Setelah menjalankan notebook ini Anda dapat:
# - Menjelaskan apa itu DuckDB dan kapan perlu dipakai
# - Membuat koneksi DuckDB (in-memory maupun file)
# - Mengeksekusi SQL dasar: `SELECT`, `WHERE`, `ORDER BY`, `GROUP BY`, `HAVING`
# - Menggunakan fungsi jendela (`ROW_NUMBER`, `RANK`, `LAG`, `LEAD`, running total)
# - Menulis CTE (`WITH`) dan `CASE` expression untuk analisis kompleks
# - Mendaftarkan DataFrame Pandas dan membandingkan performa Pandas vs DuckDB
# - Mengekspor hasil query ke CSV/Parquet

# %% [markdown]
# ## 🗓️ Agenda Ringkas
#
# | Waktu | Topik |
# |-------|-------|
# | 13:00 - 13:30 | Pengenalan DuckDB & Setup |
# | 13:30 - 15:00 | SQL Analitik & Window Functions |
# | 15:00 - 15:30 | Integrasi DuckDB + Pandas & Export |

# %% [markdown]
# ## 🛠️ Setup Lingkungan
#
# ```bash
# uv sync
# uv run jupyter notebook
#
# # atau manual
# python -m venv .venv
# source .venv/bin/activate        # macOS/Linux
# .venv\Scripts\activate           # Windows
# pip install duckdb pandas numpy pyarrow jupyter
# jupyter notebook
# ```

# %%
import warnings
from pathlib import Path

import duckdb
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

warnings.filterwarnings('ignore')
pd.options.display.float_format = '{:,.2f}'.format
sns.set_theme(style='whitegrid', palette='deep')

print(f"DuckDB version: {duckdb.__version__}")
print(f"Pandas version: {pd.__version__}")
# Out:
# DuckDB version: 1.4.1
# Pandas version: 2.3.3

# %% [markdown]
# ## 🔌 Membuat Koneksi DuckDB
# DuckDB dapat berjalan sepenuhnya di memori atau disimpan sebagai file `.duckdb` untuk reuse.

# %%
# In-memory connection (data hilang saat session selesai)
conn = duckdb.connect(database=':memory:')
print(conn)

# Contoh persistent database (ditutup lagi setelah check)
persistent_path = Path('duckdb_sessions') / 'analytics.duckdb'
persistent_path.parent.mkdir(parents=True, exist_ok=True)
persistent_conn = duckdb.connect(database=str(persistent_path))
print(f"Persistent DB path: {persistent_path.resolve()}")
persistent_conn.close()
# Out:
# <_duckdb.DuckDBPyConnection object at 0x7ddccc276170>
# Persistent DB path: /home/rizko/coding/python/project/data-science/day1/session2_duckdb/notebooks/duckdb_sessions/analytics.duckdb

# %% [markdown]
# ## 📁 Memuat Dataset RUP 2025
# Kita akan menggunakan dataset yang sama seperti sesi Pandas (Parquet). Blok berikut mencari file secara relatif dari beberapa lokasi agar notebook portable.

# %%
DATASET_FILENAME = 'RUP-PaketPenyedia-Terumumkan-2025.parquet'
candidate_paths = [
    Path('../../../datasets/rup') / DATASET_FILENAME,
    Path('../../datasets/rup') / DATASET_FILENAME,
    Path('../datasets/rup') / DATASET_FILENAME,
    Path('datasets/rup') / DATASET_FILENAME,
]
for path in candidate_paths:
    if path.exists():
        DATA_PATH = path.resolve()
        break
else:
    raise FileNotFoundError('Dataset RUP tidak ditemukan. Pastikan folder datasets tersedia.')

print(f"Dataset path: {DATA_PATH}")
# Out:
# Dataset path: /home/rizko/coding/python/project/data-science/datasets/rup/RUP-PaketPenyedia-Terumumkan-2025.parquet

# %%
# Load Parquet langsung ke DuckDB table 'rup'
conn.execute("CREATE OR REPLACE TABLE rup AS SELECT * FROM read_parquet(?)", [str(DATA_PATH)])
row_count = conn.execute("SELECT COUNT(*) FROM rup").fetchone()[0]
col_count = len(conn.execute('PRAGMA table_info(rup)').fetchall())
print(f"Total rows loaded: {row_count:,}")
print(f"Columns: {col_count}")
# Out:
# Total rows loaded: 16,430
# Columns: 48

# %% [markdown]
# ## 👀 Quick Peek dengan SQL

# %%
conn.execute("SELECT * FROM rup LIMIT 5").df()
# Out:
#    tahun_anggaran kd_klpd                  nama_klpd jenis_klpd  kd_satker  \
# 0            2025    D197  Provinsi Kalimantan Barat   PROVINSI     264455
# 1            2025    D197  Provinsi Kalimantan Barat   PROVINSI     264456
# 2            2025    D197  Provinsi Kalimantan Barat   PROVINSI     264456
# 3            2025    D197  Provinsi Kalimantan Barat   PROVINSI     264456
# 4            2025    D197  Provinsi Kalimantan Barat   PROVINSI     264456
#
#             kd_satker_str                                        nama_satker  \
# 0  1.02.0.00.0.00.03.0000         RUMAH SAKIT JIWA PROVINSI KALIMANTAN BARAT
# 1  1.03.0.00.0.00.01.0000  DINAS PEKERJAAN UMUM DAN PENATAAN RUANG PROVIN...
# 2  1.03.0.00.0.00.01.0000  DINAS PEKERJAAN UMUM DAN PENATAAN RUANG PROVIN...
# 3  1.03.0.00.0.00.01.0000  DINAS PEKERJAAN UMUM DAN PENATAAN RUANG PROVIN...
# 4  1.03.0.00.0.00.01.0000  DINAS PEKERJAAN UMUM DAN PENATAAN RUANG PROVIN...
#
#      kd_rup                                         nama_paket        pagu  \
# 0  53540979           Belanja Bahan Makanan dan Minuman Pasien  7700000000
# 1  53688068  Perencanaan Rehabilitasi Gedung UPT Pengujian ...   300000000
# 2  53699505  PENGAWASAN TEKNIS PENGGANTIAN/PEMBANGUNAN JEMB...  1200000000
# 3  53700150  PENGAWASAN TEKNIS PENINGKATAN JALAN TANJUNG  M...  1200000000
# 4  53700183  PENGAWASAN TEKNIS PENINGKATAN JALAN MARAU  AIR...  1500000000
#
#    ...  status_umumkan_rup status_dikecualikan alasan_dikecualikan  \
# 0  ...          Terumumkan               False
# 1  ...          Terumumkan               False                None
# 2  ...          Terumumkan               False                None
# 3  ...          Terumumkan               False                None
# 4  ...          Terumumkan               False                None
#
#   tahun_pertama kode_rup_tahun_pertama nomor_kontrak spp_aspek_ekonomi  \
# 0          None                   None          None             False
# 1          None                   None          None             False
# 2          None                   None          None              True
# 3          None                   None          None              True
# 4          None                   None          None              True
#
#   spp_aspek_sosial spp_aspek_lingkungan _event_date
# 0            False                False  2025-11-05
# 1            False                False  2025-11-05
# 2             True                 True  2025-11-05
# 3             True                 True  2025-11-05
# 4             True                 True  2025-11-05
#
# [5 rows x 48 columns]

# %%
conn.execute("SELECT nama_paket, pagu, metode_pengadaan FROM rup LIMIT 10").df()
# Out:
#                                           nama_paket        pagu  \
# 0           Belanja Bahan Makanan dan Minuman Pasien  7700000000
# 1  Perencanaan Rehabilitasi Gedung UPT Pengujian ...   300000000
# 2  PENGAWASAN TEKNIS PENGGANTIAN/PEMBANGUNAN JEMB...  1200000000
# 3  PENGAWASAN TEKNIS PENINGKATAN JALAN TANJUNG  M...  1200000000
# 4  PENGAWASAN TEKNIS PENINGKATAN JALAN MARAU  AIR...  1500000000
# 5  Belanja Alat/Bahan untuk Kegiatan Kantor- Kert...     2176000
# 6  Belanja Alat/Bahan untuk Kegiatan Kantor-Alat ...     5339800
# 7  Belanja Alat/Bahan untuk Kegiatan Kantor- Baha...     2840000
# 8  Belanja Alat/Bahan untuk Kegiatan Kantor-Bahan...     8645400
# 9  Belanja Makanan dan Minuman Rapat 5.02.01.1.02...     5440000
#
#   metode_pengadaan
# 0           Tender
# 1          Seleksi
# 2          Seleksi
# 3          Seleksi
# 4          Seleksi
# 5     E-Purchasing
# 6     E-Purchasing
# 7     E-Purchasing
# 8     E-Purchasing
# 9     E-Purchasing

# %% [markdown]
# ## 🧱 Sample Table untuk Latihan Cepat
# Selain dataset besar, kita buat tabel kecil `employees` agar konsep dasar mudah terlihat.

# %%
employees_df = pd.DataFrame(
    [
        (1, 'Alice', 'Engineering', 75_000),
        (2, 'Bob', 'Sales', 65_000),
        (3, 'Charlie', 'Engineering', 80_000),
        (4, 'David', 'Marketing', 60_000),
        (5, 'Eve', 'Engineering', 85_000),
    ],
    columns=['id', 'name', 'department', 'salary']
)
conn.execute("CREATE OR REPLACE TABLE employees AS SELECT * FROM employees_df")
conn.execute("SELECT * FROM employees").df()
# Out:
#    id     name   department  salary
# 0   1    Alice  Engineering   75000
# 1   2      Bob        Sales   65000
# 2   3  Charlie  Engineering   80000
# 3   4    David    Marketing   60000
# 4   5      Eve  Engineering   85000

# %% [markdown]
# ## 🔍 SQL Dasar: `SELECT`, `WHERE`, `ORDER BY`, `LIMIT`

# %%
print(conn.execute("SELECT * FROM employees ORDER BY salary DESC").df())
print(conn.execute("""
    SELECT name, salary
    FROM employees
    WHERE department = 'Engineering' AND salary > 78_000
""").df())
print(conn.execute("SELECT DISTINCT department FROM employees").df())
# Out:
#    id     name   department  salary
# 0   5      Eve  Engineering   85000
# 1   3  Charlie  Engineering   80000
# 2   1    Alice  Engineering   75000
# 3   2      Bob        Sales   65000
# 4   4    David    Marketing   60000
#       name  salary
# 0  Charlie   80000
# 1      Eve   85000
#     department
# 0    Marketing
# 1        Sales
# 2  Engineering

# %% [markdown]
# ## 📊 Aggregations & GROUP BY pada RUP

# %%
conn.execute("""
    SELECT
        metode_pengadaan,
        COUNT(*) AS jumlah_paket,
        SUM(pagu) AS total_pagu,
        AVG(pagu) AS rata_rata_pagu
    FROM rup
    GROUP BY metode_pengadaan
    ORDER BY total_pagu DESC
""").df()
# Out:
#       metode_pengadaan  jumlah_paket         total_pagu   rata_rata_pagu
# 0   Pengadaan Langsung          4515 706,994,610,990.00   156,587,953.71
# 1         E-Purchasing         11245 644,444,464,651.00    57,309,423.27
# 2               Tender            77 569,147,597,582.00 7,391,527,241.32
# 3         Dikecualikan           497 148,135,925,757.00   298,060,212.79
# 4              Seleksi            44  32,411,774,371.00   736,631,235.70
# 5  Penunjukan Langsung            48   7,201,474,767.00   150,030,724.31
# 6         Tender Cepat             3   3,328,240,000.00 1,109,413,333.33
# 7               Kontes             1       1,984,000.00     1,984,000.00

# %% [markdown]
# ## 🔢 GROUP BY Multi Kolom + HAVING

# %%
conn.execute("""
    SELECT
        metode_pengadaan,
        jenis_pengadaan,
        COUNT(*) AS jumlah,
        SUM(pagu) AS total
    FROM rup
    GROUP BY metode_pengadaan, jenis_pengadaan
    HAVING COUNT(*) > 100
    ORDER BY total DESC
    LIMIT 10
""").df()
# Out:
#      metode_pengadaan       jenis_pengadaan  jumlah              total
# 0  Pengadaan Langsung  Pekerjaan Konstruksi    2780 565,028,368,352.00
# 1        E-Purchasing                Barang    9983 507,550,552,891.00
# 2        E-Purchasing          Jasa Lainnya    1183 129,190,229,383.00
# 3        Dikecualikan                Barang     234 125,347,636,402.00
# 4  Pengadaan Langsung      Jasa Konsultansi    1237  76,134,399,437.00
# 5  Pengadaan Langsung          Jasa Lainnya     201  43,424,234,462.00
# 6        Dikecualikan          Jasa Lainnya     263  22,788,289,355.00
# 7  Pengadaan Langsung                Barang     297  22,407,608,739.00

# %% [markdown]
# ## 🎯 HAVING untuk Filter Setelah Aggregasi

# %%
conn.execute("""
    SELECT
        nama_satker,
        COUNT(*) AS jumlah_paket,
        SUM(pagu) AS total_pagu
    FROM rup
    GROUP BY nama_satker
    HAVING COUNT(*) > 25 AND SUM(pagu) > 1_000_000_000
    ORDER BY total_pagu DESC
    LIMIT 15
""").df()
# Out:
#                                           nama_satker  jumlah_paket  \
# 0   DINAS PEKERJAAN UMUM DAN PENATAAN RUANG PROVIN...          2428
# 1             RUMAH SAKIT UMUM DAERAH DOKTER SOEDARSO           231
# 2       DINAS PERUMAHAN RAKYAT DAN KAWASAN PERMUKIMAN          1711
# 3   DINAS PENDIDIKAN DAN KEBUDAYAAN PROVINSI KALIM...           688
# 4   SEKRETARIAT DEWAN PERWAKILAN RAKYAT DAERAH PRO...           367
# 5                  SEKRETARIAT DAERAH PROVINSI KALBAR           283
# 6          RUMAH SAKIT JIWA PROVINSI KALIMANTAN BARAT           104
# 7   DINAS TANAMAN PANGAN DAN HORTIKULTURA PROVINSI...           288
# 8           DINAS KESEHATAN PROVINSI KALIMANTAN BARAT           251
# 9   BADAN KEUANGAN DAN ASET DAERAH PROVINSI KALIMA...           567
# 10  DINAS KEPEMUDAAN, OLAHRAGA DAN PARIWISATA PROV...           290
# 11  DINAS PERKEBUNAN DAN PETERNAKAN PROVINSI KALIM...           291
# 12  DINAS KOMUNIKASI DAN INFORMATIKA PROVINSI KALI...           367
# 13             DINAS SOSIAL PROVINSI KALIMANTAN BARAT           256
# 14  BADAN PENDAPATAN DAERAH PROVINSI KALIMANTAN BARAT           146
#
#            total_pagu
# 0  841,492,369,155.00
# 1  331,063,820,430.00
# 2  282,709,739,900.00
# 3  203,875,269,731.00
# 4   71,445,025,587.00
# 5   48,242,938,910.00
# 6   43,546,134,778.00
# 7   23,941,927,599.00
# 8   17,933,054,839.00
# 9   15,665,976,555.00
# 10  14,328,767,146.00
# 11  13,565,650,258.00
# 12  13,507,286,284.00
# 13  10,718,450,282.00
# 14   9,699,219,274.00

# %% [markdown]
# ## 🧮 Ordering & NULL Handling

# %%
conn.execute("""
    SELECT nama_paket, pagu, metode_pengadaan
    FROM rup
    ORDER BY pagu DESC NULLS LAST
    LIMIT 20
""").df()
# Out:
#                                            nama_paket         pagu  \
# 0            Belanja Barang dan Jasa BOSP-BOS Reguler  74802424962
# 1              Belanja Obat-Obatan-Obat - Obat-obatan  55565778076
# 2                 PENINGKATAN JALAN SAYAN - KOTA BARU  37000000000
# 3   Belanja Obat-Obatan-Obat-Obatan Lainnya - Baha...  34239274690
# 4   Belanja Modal Bangunan Kesehatan - Pembangunan...  32451362000
# 5        PENINGKATAN JALAN SIMPANG MEDANG - NANGA MAU  30000000000
# 6           PENINGKATAN JALAN SUKADANA - TELUK BATANG  26000000000
# 7                   PENINGKATAN JALAN MARAU  AIR UPAS  26000000000
# 8          PENINGKATAN JALAN BATAS KOTA SAMBAS  SUBAH  26000000000
# 9             PENINGKATAN JALAN PESAGUAN  KENDAWANGAN  26000000000
# 10  Belanja Suku Cadang-Suku Cadang Alat Kedoktera...  25629508183
# 11     Belanja Makanan dan Minuman Aktivitas Lapangan  23634000000
# 12  Belanja Modal Peralatan dan Mesin BOSP-BOS Reg...  22374929915
# 13  PENGGANTIAN/PEMBANGUNAN JEMBATAN RUAS JALAN SE...  22000000000
# 14       PENINGKATAN JALAN TANJUNG  MARAU (DBH SAWIT)  21843942000
# 15                                 Kabupaten Mempawah  21100000000
# 16  PENGGANTIAN/PEMBANGUNAN JEMBATAN RUAS JALAN BA...  20000000000
# 17  Belanja Bahan-Bahan Kimia - Alat/Bahan Laborat...  18001993863
# 18                   PENINGKATAN JALAN BODOK - MELIAU  17000000000
# 19  PENGADAAN DAN PEMASANGAN JEMBATAN PANEL RUAS J...  16608200250
#
#       metode_pengadaan
# 0         Dikecualikan
# 1         E-Purchasing
# 2               Tender
# 3         E-Purchasing
# 4               Tender
# 5               Tender
# 6               Tender
# 7               Tender
# 8               Tender
# 9               Tender
# 10        E-Purchasing
# 11  Pengadaan Langsung
# 12        Dikecualikan
# 13              Tender
# 14              Tender
# 15  Pengadaan Langsung
# 16              Tender
# 17        E-Purchasing
# 18              Tender
# 19              Tender

# %% [markdown]
# ## 🧱 Window Functions: `ROW_NUMBER`, `RANK`, `DENSE_RANK`

# %%
conn.execute("""
    SELECT
        nama_paket,
        pagu,
        metode_pengadaan,
        ROW_NUMBER() OVER (ORDER BY pagu DESC) AS row_num,
        RANK() OVER (ORDER BY pagu DESC) AS rank,
        DENSE_RANK() OVER (ORDER BY pagu DESC) AS dense_rank
    FROM rup
    ORDER BY pagu DESC
    LIMIT 15
""").df()
# Out:
#                                            nama_paket         pagu  \
# 0            Belanja Barang dan Jasa BOSP-BOS Reguler  74802424962
# 1              Belanja Obat-Obatan-Obat - Obat-obatan  55565778076
# 2                 PENINGKATAN JALAN SAYAN - KOTA BARU  37000000000
# 3   Belanja Obat-Obatan-Obat-Obatan Lainnya - Baha...  34239274690
# 4   Belanja Modal Bangunan Kesehatan - Pembangunan...  32451362000
# 5        PENINGKATAN JALAN SIMPANG MEDANG - NANGA MAU  30000000000
# 6             PENINGKATAN JALAN PESAGUAN  KENDAWANGAN  26000000000
# 7                   PENINGKATAN JALAN MARAU  AIR UPAS  26000000000
# 8          PENINGKATAN JALAN BATAS KOTA SAMBAS  SUBAH  26000000000
# 9           PENINGKATAN JALAN SUKADANA - TELUK BATANG  26000000000
# 10  Belanja Suku Cadang-Suku Cadang Alat Kedoktera...  25629508183
# 11     Belanja Makanan dan Minuman Aktivitas Lapangan  23634000000
# 12  Belanja Modal Peralatan dan Mesin BOSP-BOS Reg...  22374929915
# 13  PENGGANTIAN/PEMBANGUNAN JEMBATAN RUAS JALAN SE...  22000000000
# 14       PENINGKATAN JALAN TANJUNG  MARAU (DBH SAWIT)  21843942000
#
#       metode_pengadaan  row_num  rank  dense_rank
# 0         Dikecualikan        1     1           1
# 1         E-Purchasing        2     2           2
# 2               Tender        3     3           3
# 3         E-Purchasing        4     4           4
# 4               Tender        5     5           5
# 5               Tender        6     6           6
# 6               Tender       10     7           7
# 7               Tender        8     7           7
# 8               Tender        9     7           7
# 9               Tender        7     7           7
# 10        E-Purchasing       11    11           8
# 11  Pengadaan Langsung       12    12           9
# 12        Dikecualikan       13    13          10
# 13              Tender       14    14          11
# 14              Tender       15    15          12

# %% [markdown]
# ## 🧩 PARTITION BY: Top Paket per Metode

# %%
conn.execute("""
    WITH ranked AS (
        SELECT
            nama_paket,
            pagu,
            metode_pengadaan,
            ROW_NUMBER() OVER (
                PARTITION BY metode_pengadaan
                ORDER BY pagu DESC
            ) AS rank_in_metode
        FROM rup
    )
    SELECT *
    FROM ranked
    WHERE rank_in_metode <= 5
    ORDER BY metode_pengadaan, rank_in_metode
""").df()
# Out:
#                                            nama_paket         pagu  \
# 0            Belanja Barang dan Jasa BOSP-BOS Reguler  74802424962
# 1   Belanja Modal Peralatan dan Mesin BOSP-BOS Reg...  22374929915
# 2   Belanja Modal Aset Tetap Lainnya BOSP-BOS Reguler   8927369139
# 3                             Belanja Tagihan Listrik   5816798000
# 4                             Belanja Tagihan Listrik   5363653291
# 5              Belanja Obat-Obatan-Obat - Obat-obatan  55565778076
# 6   Belanja Obat-Obatan-Obat-Obatan Lainnya - Baha...  34239274690
# 7   Belanja Suku Cadang-Suku Cadang Alat Kedoktera...  25629508183
# 8   Belanja Bahan-Bahan Kimia - Alat/Bahan Laborat...  18001993863
# 9   Belanja Modal Alat Kedokteran Umum - Alat Kedo...  12502468190
# 10  Belanja Alat/Bahan untuk Kegiatan Kantor-Alat ...      1984000
# 11     Belanja Makanan dan Minuman Aktivitas Lapangan  23634000000
# 12                                 Kabupaten Mempawah  21100000000
# 13                                   Kabupaten Melawi  13800000000
# 14                               Kabupaten Bengkayang  12350000000
# 15                                    Kota Singkawang   6400000000
# 16  SURVEY KONDISI JALAN PROVINSI KALIMANTAN BARAT...   1500000000
# 17  Belanja Jasa Konsultansi Berorientasi Bidang-K...    700000000
# 18  Peningkatan kompetensi dan kualifikasi SDM kes...    656180255
# 19  Belanja Modal Alat Peraga Praktek Sekolah Bida...    600000000
# 20  Belanja Modal Mebel_Pengadaan Mebel Sekolah Pe...    545272580
# 21  SURVEY KONDISI DAN INVENTARIS JEMBATAN PROVINS...   1800000000
# 22  PENGAWASAN TEKNIS PENINGKATAN JALAN MARAU  AIR...   1500000000
# 23  Perencanaan Rehabiitasi Gedung Pemerintah dan ...   1500000000
# 24  Belanja Modal Bangunan Kesehatan - Pembangunan...   1248638000
# 25  PENGAWASAN TEKNIS PENGGANTIAN/PEMBANGUNAN JEMB...   1200000000
# 26                PENINGKATAN JALAN SAYAN - KOTA BARU  37000000000
# 27  Belanja Modal Bangunan Kesehatan - Pembangunan...  32451362000
# 28       PENINGKATAN JALAN SIMPANG MEDANG - NANGA MAU  30000000000
# 29            PENINGKATAN JALAN PESAGUAN  KENDAWANGAN  26000000000
# 30         PENINGKATAN JALAN BATAS KOTA SAMBAS  SUBAH  26000000000
# 31  Belanja Jasa Tenaga Kebersihan berupa Jasa Pra...   1948000000
# 32  Belanja Jasa Tenaga Kebersihan berupa Jasa Keb...    767040000
# 33                   Belanja Jasa Tenaga Keamanan (B)    613200000
#
#        metode_pengadaan  rank_in_metode
# 0          Dikecualikan               1
# 1          Dikecualikan               2
# 2          Dikecualikan               3
# 3          Dikecualikan               4
# 4          Dikecualikan               5
# 5          E-Purchasing               1
# 6          E-Purchasing               2
# 7          E-Purchasing               3
# 8          E-Purchasing               4
# 9          E-Purchasing               5
# 10               Kontes               1
# 11   Pengadaan Langsung               1
# 12   Pengadaan Langsung               2
# 13   Pengadaan Langsung               3
# 14   Pengadaan Langsung               4
# 15   Pengadaan Langsung               5
# 16  Penunjukan Langsung               1
# 17  Penunjukan Langsung               2
# 18  Penunjukan Langsung               3
# 19  Penunjukan Langsung               4
# 20  Penunjukan Langsung               5
# 21              Seleksi               1
# 22              Seleksi               2
# 23              Seleksi               3
# 24              Seleksi               4
# 25              Seleksi               5
# 26               Tender               1
# 27               Tender               2
# 28               Tender               3
# 29               Tender               4
# 30               Tender               5
# 31         Tender Cepat               1
# 32         Tender Cepat               2
# 33         Tender Cepat               3

# %% [markdown]
# ## 📈 LAG & LEAD untuk Time Series

# %%
conn.execute("""
    WITH daily AS (
        SELECT
            DATE_TRUNC('day', tgl_pengumuman_paket) AS tanggal,
            COUNT(*) AS jumlah_paket
        FROM rup
        WHERE tgl_pengumuman_paket IS NOT NULL
        GROUP BY 1
    )
    SELECT
        tanggal,
        jumlah_paket,
        LAG(jumlah_paket) OVER (ORDER BY tanggal) AS prev_day,
        LEAD(jumlah_paket) OVER (ORDER BY tanggal) AS next_day,
        jumlah_paket - LAG(jumlah_paket) OVER (ORDER BY tanggal) AS delta
    FROM daily
    ORDER BY tanggal
    LIMIT 20
""").df()
# Out:
#       tanggal  jumlah_paket  prev_day  next_day  delta
# 0  2024-11-22             1      <NA>         1   <NA>
# 1  2024-12-09             1         1         2      0
# 2  2024-12-12             2         1         1      1
# 3  2024-12-16             1         2         4     -1
# 4  2024-12-17             4         1        30      3
# 5  2024-12-19            30         4         2     26
# 6  2024-12-20             2        30         5    -28
# 7  2024-12-21             5         2         9      3
# 8  2024-12-23             9         5       131      4
# 9  2024-12-25           131         9        29    122
# 10 2024-12-27            29       131         1   -102
# 11 2024-12-29             1        29        11    -28
# 12 2024-12-30            11         1        47     10
# 13 2024-12-31            47        11         3     36
# 14 2025-01-01             3        47         6    -44
# 15 2025-01-06             6         3        29      3
# 16 2025-01-07            29         6        35     23
# 17 2025-01-08            35        29        97      6
# 18 2025-01-09            97        35        96     62
# 19 2025-01-10            96        97        31     -1

# %% [markdown]
# ## 📉 Running Total & Moving Average

# %%
conn.execute("""
    WITH daily AS (
        SELECT
            DATE_TRUNC('day', tgl_pengumuman_paket) AS tanggal,
            COUNT(*) AS jumlah_paket
        FROM rup
        WHERE tgl_pengumuman_paket IS NOT NULL
        GROUP BY 1
    )
    SELECT
        tanggal,
        jumlah_paket,
        SUM(jumlah_paket) OVER (
            ORDER BY tanggal
            ROWS BETWEEN UNBOUNDED PRECEDING AND CURRENT ROW
        ) AS running_total,
        AVG(jumlah_paket) OVER (
            ORDER BY tanggal
            ROWS BETWEEN 6 PRECEDING AND CURRENT ROW
        ) AS moving_avg_7day
    FROM daily
    ORDER BY tanggal
    LIMIT 25
""").df()
# Out:
#       tanggal  jumlah_paket  running_total  moving_avg_7day
# 0  2024-11-22             1           1.00             1.00
# 1  2024-12-09             1           2.00             1.00
# 2  2024-12-12             2           4.00             1.33
# 3  2024-12-16             1           5.00             1.25
# 4  2024-12-17             4           9.00             1.80
# 5  2024-12-19            30          39.00             6.50
# 6  2024-12-20             2          41.00             5.86
# 7  2024-12-21             5          46.00             6.43
# 8  2024-12-23             9          55.00             7.57
# 9  2024-12-25           131         186.00            26.00
# 10 2024-12-27            29         215.00            30.00
# 11 2024-12-29             1         216.00            29.57
# 12 2024-12-30            11         227.00            26.86
# 13 2024-12-31            47         274.00            33.29
# 14 2025-01-01             3         277.00            33.00
# 15 2025-01-06             6         283.00            32.57
# 16 2025-01-07            29         312.00            18.00
# 17 2025-01-08            35         347.00            18.86
# 18 2025-01-09            97         444.00            32.57
# 19 2025-01-10            96         540.00            44.71
# 20 2025-01-11            31         571.00            42.43
# 21 2025-01-13            95         666.00            55.57
# 22 2025-01-14            37         703.00            60.00
# 23 2025-01-15           215         918.00            86.57
# 24 2025-01-16           104       1,022.00            96.43

# %% [markdown]
# ## 🧵 Common Table Expressions (CTE)

# %%
conn.execute("""
    WITH satker_metrics AS (
        SELECT
            nama_satker,
            COUNT(*) AS total_paket,
            SUM(pagu) AS total_pagu,
            AVG(pagu) AS avg_pagu
        FROM rup
        GROUP BY nama_satker
    ), ranked AS (
        SELECT *, ROW_NUMBER() OVER (ORDER BY total_pagu DESC) AS rank_by_pagu
        FROM satker_metrics
    )
    SELECT * FROM ranked
    WHERE rank_by_pagu <= 10
""").df()
# Out:
#                                          nama_satker  total_paket  \
# 0  DINAS PEKERJAAN UMUM DAN PENATAAN RUANG PROVIN...         2428
# 1            RUMAH SAKIT UMUM DAERAH DOKTER SOEDARSO          231
# 2      DINAS PERUMAHAN RAKYAT DAN KAWASAN PERMUKIMAN         1711
# 3  DINAS PENDIDIKAN DAN KEBUDAYAAN PROVINSI KALIM...          688
# 4  SEKRETARIAT DEWAN PERWAKILAN RAKYAT DAERAH PRO...          367
# 5                 SEKRETARIAT DAERAH PROVINSI KALBAR          283
# 6         RUMAH SAKIT JIWA PROVINSI KALIMANTAN BARAT          104
# 7  DINAS TANAMAN PANGAN DAN HORTIKULTURA PROVINSI...          288
# 8          DINAS KESEHATAN PROVINSI KALIMANTAN BARAT          251
# 9  BADAN KEUANGAN DAN ASET DAERAH PROVINSI KALIMA...          567
#
#           total_pagu         avg_pagu  rank_by_pagu
# 0 841,492,369,155.00   346,578,405.75             1
# 1 331,063,820,430.00 1,433,176,711.82             2
# 2 282,709,739,900.00   165,230,707.13             3
# 3 203,875,269,731.00   296,330,333.91             4
# 4  71,445,025,587.00   194,673,094.24             5
# 5  48,242,938,910.00   170,469,748.80             6
# 6  43,546,134,778.00   418,712,834.40             7
# 7  23,941,927,599.00    83,131,693.05             8
# 8  17,933,054,839.00    71,446,433.62             9
# 9  15,665,976,555.00    27,629,588.28            10

# %% [markdown]
# ## 🎛️ CASE Expression untuk Kategori

# %%
conn.execute("""
    SELECT
        CASE
            WHEN pagu < 100_000_000 THEN 'Small'
            WHEN pagu < 1_000_000_000 THEN 'Medium'
            WHEN pagu < 5_000_000_000 THEN 'Large'
            ELSE 'Very Large'
        END AS kategori_pagu,
        COUNT(*) AS jumlah,
        SUM(pagu) AS total_pagu
    FROM rup
    GROUP BY 1
    ORDER BY total_pagu DESC
""").df()
# Out:
#   kategori_pagu  jumlah         total_pagu
# 0    Very Large      59 919,847,571,117.00
# 1        Medium    3834 768,229,731,385.00
# 2         Large     146 261,714,890,046.00
# 3         Small   12391 161,873,879,570.00

# %% [markdown]
# ## 🐼 Integrasi Pandas + DuckDB
# DuckDB bisa langsung men-query DataFrame Pandas tanpa perlu menulis ke disk.

# %%
rup_df = conn.execute("SELECT * FROM rup").df()
print(rup_df.shape)

conn.register('rup_df', rup_df)
conn.execute("""
    SELECT metode_pengadaan, COUNT(*) AS jumlah, SUM(pagu) AS total_pagu
    FROM rup_df
    GROUP BY metode_pengadaan
    ORDER BY total_pagu DESC
""").df()
# Out:
# (16430, 48)
#       metode_pengadaan  jumlah         total_pagu
# 0   Pengadaan Langsung    4515 706,994,610,990.00
# 1         E-Purchasing   11245 644,444,464,651.00
# 2               Tender      77 569,147,597,582.00
# 3         Dikecualikan     497 148,135,925,757.00
# 4              Seleksi      44  32,411,774,371.00
# 5  Penunjukan Langsung      48   7,201,474,767.00
# 6         Tender Cepat       3   3,328,240,000.00
# 7               Kontes       1       1,984,000.00

# %%
result = duckdb.query("""
    SELECT jenis_pengadaan, AVG(pagu) AS avg_pagu
    FROM rup_df
    GROUP BY jenis_pengadaan
    ORDER BY avg_pagu DESC
""").df()
result
# Out:
#         jenis_pengadaan       avg_pagu
# 0  Pekerjaan Konstruksi 390,219,417.71
# 1          Jasa Lainnya 119,840,940.69
# 2      Jasa Konsultansi  84,955,917.24
# 3                Barang  63,174,397.11
# 4         Barang;Barang  41,500,000.00
# 5                  None     632,500.00

# %% [markdown]
# ## ⚡ Benchmark Pandas vs DuckDB

# %%
import time
np.random.seed(42)
n_rows = 200_000
benchmark_df = pd.DataFrame({
    'category': np.random.choice(['A', 'B', 'C', 'D', 'E'], size=n_rows),
    'value': np.random.randint(0, 1_000_000, size=n_rows)
})

start = time.time()
pandas_group = benchmark_df.groupby('category')['value'].agg(['count', 'sum', 'mean'])
pandas_time = time.time() - start

conn.register('benchmark_df', benchmark_df)
start = time.time()
duckdb_group = conn.execute("""
    SELECT category, COUNT(*) AS count, SUM(value) AS sum, AVG(value) AS mean
    FROM benchmark_df
    GROUP BY category
""").df()
duckdb_time = time.time() - start

print(f"Pandas time: {pandas_time:.4f}s")
print(f"DuckDB time: {duckdb_time:.4f}s")
print(f"Speedup: {pandas_time / duckdb_time:.2f}x")
# Out:
# Pandas time: 0.0355s
# DuckDB time: 0.0062s
# Speedup: 5.69x

# %% [markdown]
# ## 💾 Export Hasil Query

# %%
export_dir = Path.cwd() / 'duckdb_exports'
export_dir.mkdir(parents=True, exist_ok=True)

csv_path = export_dir / 'employees_export.csv'
parquet_path = export_dir / 'employees_export.parquet'

conn.execute(f"""
    COPY (
        SELECT * FROM employees
    ) TO '{csv_path.as_posix()}'
    (HEADER, DELIMITER ',')
""")

conn.execute(f"""
    COPY (
        SELECT * FROM employees
    ) TO '{parquet_path.as_posix()}'
    (FORMAT PARQUET)
""")

print(f"Export selesai ke {csv_path} dan {parquet_path}")
# Out:
# ---------------------------------------------------------------------------
# IOException                               Traceback (most recent call last)
# Cell In[26], line 1
# ----> 1 conn.execute("""
#       2     COPY (
#       3         SELECT * FROM employees
#       4     ) TO 'day1/session2_duckdb/notebooks/employees_export.csv'
#       5     (HEADER, DELIMITER ',')
#       6 """)
#       8 conn.execute("""
#       9     COPY (
#      10         SELECT * FROM employees
#      11     ) TO 'day1/session2_duckdb/notebooks/employees_export.parquet'
#      12     (FORMAT PARQUET)
#      13 """)
#      15 print("Export selesai (CSV & Parquet)")
#
# IOException: IO Error: Cannot open file "day1/session2_duckdb/notebooks/employees_export.csv": No such file or directory

# %% [markdown]
# ## ✍️ Latihan Mandiri
#
# 1. Buat query untuk top 10 satker berdasarkan jumlah paket, bukan pagu.
# 2. Gunakan window function `RANK()` untuk mencari 3 paket terbesar pada setiap satker.
# 3. Hitung pertumbuhan month-over-month paket pengumuman menggunakan `LAG` dan tampilkan persentasenya.
# 4. Buat pivot sederhana: metode pengadaan sebagai baris, jenis pengadaan sebagai kolom, isi = jumlah paket.
# 5. Bandingkan waktu eksekusi query agregasi kompleks menggunakan Pandas vs DuckDB pada dataset Anda sendiri.
# 6. Ekspor hasil query favorit Anda ke format Parquet dan Excel untuk dibagikan ke tim.

# %% [markdown]
# ## ✅ Ringkasan & Next Steps
#
# - DuckDB cocok untuk workload analitik (OLAP) dengan sintaks SQL lengkap.
# - Window functions dan CTE membuat analisis kompleks tetap readable.
# - Integrasi dengan Pandas memudahkan bridging antara dunia SQL dan Pythonic data science.
# - Gunakan DuckDB langsung di atas Parquet/CSV tanpa ETL tambahan.
#
# **Lanjutkan:** `day1/session3_visualization` untuk memvisualisasikan insight dari query DuckDB ini.

# %%
conn.close()
print("✅ DuckDB connection closed")

# %% [markdown]
# # 📊 Sesi 1: Python & Pandas untuk Analisis Data
#
# Notebook ini menjadi pendamping slide `slides/01_session1_pandas.md` agar peserta bisa langsung mencoba setiap konsep yang dibahas di kelas.
#
# **Fokus:** eksplorasi data, seleksi/filtering, agregasi, penanganan data kualitas, dan visualisasi dasar menggunakan Pandas.
# **Dataset:** RUP Paket Penyedia Terumumkan 2025 (16.430 baris, 35 kolom).

# %% [markdown]
# ## 🎯 Tujuan Sesi
#
# Setelah menyelesaikan notebook ini Anda dapat:
# - Memuat dan mengeksplorasi dataset Parquet menggunakan Pandas
# - Melihat ringkasan struktur data (`head`, `info`, `describe`)
# - Melakukan seleksi kolom/baris dengan `.loc` dan `.iloc`
# - Melakukan filtering (boolean dan `query`)
# - Menggunakan `groupby` untuk agregasi dan ringkasan
# - Menangani missing values, string, dan tanggal
# - Membuat visualisasi dasar dan menemukan insight awal

# %% [markdown]
# ## 🛠️ Setup Lingkungan
#
# ```bash
# # Opsi 1 (disarankan): uv
# uv sync
# uv run jupyter notebook
#
# # Opsi 2: venv + pip
# python -m venv .venv
# source .venv/bin/activate      # Linux / macOS
# .venv\Scripts\activate         # Windows
# pip install pandas numpy jupyter pyarrow openpyxl seaborn matplotlib
# jupyter notebook
# ```

# %%
import warnings
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns

warnings.filterwarnings('ignore')

# Konfigurasi tampilan DataFrame
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', 100)
pd.set_option('display.float_format', '{:.2f}'.format)

# Konfigurasi visualisasi
plt.style.use('seaborn-v0_8')
sns.set_palette('husl')

print(f"Pandas version: {pd.__version__}")
print(f"NumPy version: {np.__version__}")
# Out:
# Pandas version: 2.3.3
# NumPy version: 2.3.4

# %% [markdown]
# ## 📁 Load Dataset RUP 2025
#
# File Parquet tersimpan di folder `datasets/rup`. Blok kode berikut mencari file tersebut secara relatif dari beberapa kemungkinan lokasi agar notebook tetap portable.

# %%
DATASET_FILENAME = 'RUP-PaketPenyedia-Terumumkan-2025.parquet'
candidate_paths = [
    Path('../../../datasets/rup') / DATASET_FILENAME,
    Path('../../datasets/rup') / DATASET_FILENAME,
    Path('../datasets/rup') / DATASET_FILENAME,
    Path('datasets/rup') / DATASET_FILENAME,
]

for path in candidate_paths:
    if path.exists():
        DATA_PATH = path
        break
else:
    raise FileNotFoundError('Dataset RUP 2025 tidak ditemukan. Pastikan folder datasets tersedia.')

print(f"Dataset path: {DATA_PATH}")
df = pd.read_parquet(DATA_PATH)
print(f"Dataset shape: {df.shape}")
print(f"Rows: {df.shape[0]:,}")
print(f"Columns: {df.shape[1]}")
# Out:
# Dataset path: ../../../datasets/rup/RUP-PaketPenyedia-Terumumkan-2025.parquet
# Dataset shape: (16430, 48)
# Rows: 16,430
# Columns: 48

# %% [markdown]
# ## 🔍 Quick Peek
# Gunakan `.head()` dan `.tail()` untuk melihat struktur data secara cepat.

# %%
df.head()
# Out:
#    tahun_anggaran kd_klpd                  nama_klpd jenis_klpd  kd_satker  \
# 0            2025    D197  Provinsi Kalimantan Barat   PROVINSI     264455
# 1            2025    D197  Provinsi Kalimantan Barat   PROVINSI     264456
# 2            2025    D197  Provinsi Kalimantan Barat   PROVINSI     264456
# 3            2025    D197  Provinsi Kalimantan Barat   PROVINSI     264456
# 4            2025    D197  Provinsi Kalimantan Barat   PROVINSI     264456
#
#             kd_satker_str                                        nama_satker  \
# 0  1.02.0.00.0.00.03.0000         RUMAH SAKIT JIWA PROVINSI KALIMANTAN BARAT
# 1  1.03.0.00.0.00.01.0000  DINAS PEKERJAAN UMUM DAN PENATAAN RUANG PROVIN...
# 2  1.03.0.00.0.00.01.0000  DINAS PEKERJAAN UMUM DAN PENATAAN RUANG PROVIN...
# 3  1.03.0.00.0.00.01.0000  DINAS PEKERJAAN UMUM DAN PENATAAN RUANG PROVIN...
# 4  1.03.0.00.0.00.01.0000  DINAS PEKERJAAN UMUM DAN PENATAAN RUANG PROVIN...
#
#      kd_rup                                         nama_paket        pagu  \
# 0  53540979           Belanja Bahan Makanan dan Minuman Pasien  7700000000
# 1  53688068  Perencanaan Rehabilitasi Gedung UPT Pengujian ...   300000000
# 2  53699505  PENGAWASAN TEKNIS PENGGANTIAN/PEMBANGUNAN JEMB...  1200000000
# 3  53700150  PENGAWASAN TEKNIS PENINGKATAN JALAN TANJUNG  M...  1200000000
# 4  53700183  PENGAWASAN TEKNIS PENINGKATAN JALAN MARAU  AIR...  1500000000
#
#    kd_metode_pengadaan metode_pengadaan kd_jenis_pengadaan   jenis_pengadaan  \
# 0                   13           Tender                  1            Barang
# 1                   15          Seleksi                  3  Jasa Konsultansi
# 2                   15          Seleksi                  3  Jasa Konsultansi
# 3                   15          Seleksi                  3  Jasa Konsultansi
# 4                   15          Seleksi                  3  Jasa Konsultansi
#
#   status_pradipa status_pdn status_ukm  \
# 0        PraDIPA        PDN        UKM
# 1    Non-PraDIPA        PDN        UKM
# 2        PraDIPA        PDN    Non-UKM
# 3        PraDIPA        PDN    Non-UKM
# 4        PraDIPA        PDN    Non-UKM
#
#                                alasan_non_ukm status_konsolidasi tipe_paket  \
# 0                                        None    Non-Konsolidasi   Penyedia
# 1                                        None    Non-Konsolidasi   Penyedia
# 2  Kompetensi tidak sesuai dengan usaha kecil    Non-Konsolidasi   Penyedia
# 3  Kompetensi tidak sesuai dengan usaha kecil    Non-Konsolidasi   Penyedia
# 4  Kompetensi tidak sesuai dengan usaha kecil    Non-Konsolidasi   Penyedia
#
#    kd_rup_swakelola kd_rup_lokal volume_pekerjaan  \
# 0               NaN         None          1 paket
# 1               NaN         None          1 Paket
# 2               NaN         None          1 Paket
# 3               NaN         None          1 Paket
# 4               NaN         None          1 Paket
#
#                                    urarian_pekerjaan  \
# 0           Belanja Bahan Makanan dan Minuman Pasien
# 1  Melakukan Perencanaan Rehabilitasi Gedung UPT ...
# 2  Pengawasan Teknis pelaksanaan Pekerjaan Pemban...
# 3  Pengawasan Teknis Pelaksanaan Pekerjaan Pening...
# 4  Pengawasan Teknis Pelaksanaan Pekerjaan Pening...
#
#                       spesifikasi_pekerjaan tgl_awal_pemilihan  \
# 0  Belanja Bahan Makanan dan Minuman Pasien         2024-11-01
# 1                     Pekerjaan Konsultansi         2024-12-01
# 2       Pengawasan Teknis Bidang Bina Marga         2024-12-01
# 3       Pengawasan Teknis Bidang Bina Marga         2024-12-01
# 4       Pengawasan Teknis Bidang Bina Marga         2024-12-01
#
#   tgl_akhir_pemilihan tgl_awal_kontrak tgl_akhir_kontrak tgl_awal_pemanfaatan  \
# 0          2024-12-01       2025-01-01        2025-12-01           2025-01-01
# 1          2025-02-01       2025-02-01        2025-04-01           2025-05-01
# 2          2024-12-01       2025-01-01        2025-12-01           2025-01-01
# 3          2024-12-01       2025-01-01        2025-12-01           2025-01-01
# 4          2024-12-01       2025-01-01        2025-12-01           2025-01-01
#
#   tgl_akhir_pemanfaatan tgl_buat_paket tgl_pengumuman_paket  \
# 0            2025-12-01     2024-11-22  2024-11-22 22:22:47
# 1            2025-12-01     2024-12-09  2024-12-09 15:52:13
# 2            2025-12-01     2024-12-10  2024-12-16 14:25:38
# 3            2025-12-01     2024-12-10  2024-12-12 17:05:24
# 4            2025-12-01     2024-12-10  2024-12-12 17:05:24
#
#               nip_ppk                          nama_ppk        username_ppk  \
# 0  197606132006041012  dr. Batara Hendra Putra Sianipar     batara.ppk24-97
# 1  198006122011011003                ISFANDIAR, ST. MT.  isfandiar.ppk24-97
# 2  196901141998031004               HARDIAN, S.T., M.T.    hardian.ppk24-97
# 3  196901141998031004               HARDIAN, S.T., M.T.    hardian.ppk24-97
# 4  196901141998031004               HARDIAN, S.T., M.T.    hardian.ppk24-97
#
#    status_aktif_rup  status_delete_rup status_umumkan_rup  \
# 0              True              False         Terumumkan
# 1              True              False         Terumumkan
# 2              True              False         Terumumkan
# 3              True              False         Terumumkan
# 4              True              False         Terumumkan
#
#    status_dikecualikan alasan_dikecualikan tahun_pertama  \
# 0                False                              None
# 1                False                None          None
# 2                False                None          None
# 3                False                None          None
# 4                False                None          None
#
#   kode_rup_tahun_pertama nomor_kontrak  spp_aspek_ekonomi  spp_aspek_sosial  \
# 0                   None          None              False             False
# 1                   None          None              False             False
# 2                   None          None               True              True
# 3                   None          None               True              True
# 4                   None          None               True              True
#
#    spp_aspek_lingkungan _event_date
# 0                 False  2025-11-05
# 1                 False  2025-11-05
# 2                  True  2025-11-05
# 3                  True  2025-11-05
# 4                  True  2025-11-05

# %%
df.head(10)
# Out:
#    tahun_anggaran kd_klpd                  nama_klpd jenis_klpd  kd_satker  \
# 0            2025    D197  Provinsi Kalimantan Barat   PROVINSI     264455
# 1            2025    D197  Provinsi Kalimantan Barat   PROVINSI     264456
# 2            2025    D197  Provinsi Kalimantan Barat   PROVINSI     264456
# 3            2025    D197  Provinsi Kalimantan Barat   PROVINSI     264456
# 4            2025    D197  Provinsi Kalimantan Barat   PROVINSI     264456
# 5            2025    D197  Provinsi Kalimantan Barat   PROVINSI     264494
# 6            2025    D197  Provinsi Kalimantan Barat   PROVINSI     264494
# 7            2025    D197  Provinsi Kalimantan Barat   PROVINSI     264494
# 8            2025    D197  Provinsi Kalimantan Barat   PROVINSI     264494
# 9            2025    D197  Provinsi Kalimantan Barat   PROVINSI     264494
#
#             kd_satker_str                                        nama_satker  \
# 0  1.02.0.00.0.00.03.0000         RUMAH SAKIT JIWA PROVINSI KALIMANTAN BARAT
# 1  1.03.0.00.0.00.01.0000  DINAS PEKERJAAN UMUM DAN PENATAAN RUANG PROVIN...
# 2  1.03.0.00.0.00.01.0000  DINAS PEKERJAAN UMUM DAN PENATAAN RUANG PROVIN...
# 3  1.03.0.00.0.00.01.0000  DINAS PEKERJAAN UMUM DAN PENATAAN RUANG PROVIN...
# 4  1.03.0.00.0.00.01.0000  DINAS PEKERJAAN UMUM DAN PENATAAN RUANG PROVIN...
# 5  5.02.0.00.0.00.02.0000  BADAN KEUANGAN DAN ASET DAERAH PROVINSI KALIMA...
# 6  5.02.0.00.0.00.02.0000  BADAN KEUANGAN DAN ASET DAERAH PROVINSI KALIMA...
# 7  5.02.0.00.0.00.02.0000  BADAN KEUANGAN DAN ASET DAERAH PROVINSI KALIMA...
# 8  5.02.0.00.0.00.02.0000  BADAN KEUANGAN DAN ASET DAERAH PROVINSI KALIMA...
# 9  5.02.0.00.0.00.02.0000  BADAN KEUANGAN DAN ASET DAERAH PROVINSI KALIMA...
#
#      kd_rup                                         nama_paket        pagu  \
# 0  53540979           Belanja Bahan Makanan dan Minuman Pasien  7700000000
# 1  53688068  Perencanaan Rehabilitasi Gedung UPT Pengujian ...   300000000
# 2  53699505  PENGAWASAN TEKNIS PENGGANTIAN/PEMBANGUNAN JEMB...  1200000000
# 3  53700150  PENGAWASAN TEKNIS PENINGKATAN JALAN TANJUNG  M...  1200000000
# 4  53700183  PENGAWASAN TEKNIS PENINGKATAN JALAN MARAU  AIR...  1500000000
# 5  53773466  Belanja Alat/Bahan untuk Kegiatan Kantor- Kert...     2176000
# 6  53773467  Belanja Alat/Bahan untuk Kegiatan Kantor-Alat ...     5339800
# 7  53773468  Belanja Alat/Bahan untuk Kegiatan Kantor- Baha...     2840000
# 8  53773469  Belanja Alat/Bahan untuk Kegiatan Kantor-Bahan...     8645400
# 9  53773470  Belanja Makanan dan Minuman Rapat 5.02.01.1.02...     5440000
#
#    kd_metode_pengadaan metode_pengadaan kd_jenis_pengadaan   jenis_pengadaan  \
# 0                   13           Tender                  1            Barang
# 1                   15          Seleksi                  3  Jasa Konsultansi
# 2                   15          Seleksi                  3  Jasa Konsultansi
# 3                   15          Seleksi                  3  Jasa Konsultansi
# 4                   15          Seleksi                  3  Jasa Konsultansi
# 5                    9     E-Purchasing                  1            Barang
# 6                    9     E-Purchasing                  1            Barang
# 7                    9     E-Purchasing                  1            Barang
# 8                    9     E-Purchasing                  1            Barang
# 9                    9     E-Purchasing                  4      Jasa Lainnya
#
#   status_pradipa status_pdn status_ukm  \
# 0        PraDIPA        PDN        UKM
# 1    Non-PraDIPA        PDN        UKM
# 2        PraDIPA        PDN    Non-UKM
# 3        PraDIPA        PDN    Non-UKM
# 4        PraDIPA        PDN    Non-UKM
# 5    Non-PraDIPA        PDN        UKM
# 6    Non-PraDIPA        PDN        UKM
# 7    Non-PraDIPA        PDN        UKM
# 8    Non-PraDIPA        PDN        UKM
# 9    Non-PraDIPA        PDN        UKM
#
#                                alasan_non_ukm status_konsolidasi tipe_paket  \
# 0                                        None    Non-Konsolidasi   Penyedia
# 1                                        None    Non-Konsolidasi   Penyedia
# 2  Kompetensi tidak sesuai dengan usaha kecil    Non-Konsolidasi   Penyedia
# 3  Kompetensi tidak sesuai dengan usaha kecil    Non-Konsolidasi   Penyedia
# 4  Kompetensi tidak sesuai dengan usaha kecil    Non-Konsolidasi   Penyedia
# 5                                        None    Non-Konsolidasi   Penyedia
# 6                                        None    Non-Konsolidasi   Penyedia
# 7                                        None    Non-Konsolidasi   Penyedia
# 8                                        None    Non-Konsolidasi   Penyedia
# 9                                        None    Non-Konsolidasi   Penyedia
#
#    kd_rup_swakelola kd_rup_lokal volume_pekerjaan  \
# 0               NaN         None          1 paket
# 1               NaN         None          1 Paket
# 2               NaN         None          1 Paket
# 3               NaN         None          1 Paket
# 4               NaN         None          1 Paket
# 5               NaN         None          1 tahun
# 6               NaN         None          1 tahun
# 7               NaN         None          1 tahun
# 8               NaN         None          1 tahun
# 9               NaN         None          1 tahun
#
#                                    urarian_pekerjaan  \
# 0           Belanja Bahan Makanan dan Minuman Pasien
# 1  Melakukan Perencanaan Rehabilitasi Gedung UPT ...
# 2  Pengawasan Teknis pelaksanaan Pekerjaan Pemban...
# 3  Pengawasan Teknis Pelaksanaan Pekerjaan Pening...
# 4  Pengawasan Teknis Pelaksanaan Pekerjaan Pening...
# 5                   Kertas; Kertas; Kertas; Kertas;
# 6  Ballpoint; Sticky Note; Penjepit Kertas; Isi C...
# 7  Beban Penggandaan; Beban Penggandaan; Cetak Ku...
# 8  Tinta; Tinta/Toner Printer; Cartridge; Tinta; ...
# 9           Makan Minum; Snack; Snack; Makan Minum;
#
#                                spesifikasi_pekerjaan tgl_awal_pemilihan  \
# 0           Belanja Bahan Makanan dan Minuman Pasien         2024-11-01
# 1                              Pekerjaan Konsultansi         2024-12-01
# 2                Pengawasan Teknis Bidang Bina Marga         2024-12-01
# 3                Pengawasan Teknis Bidang Bina Marga         2024-12-01
# 4                Pengawasan Teknis Bidang Bina Marga         2024-12-01
# 5  HVS 75 gr F4; \r\nHVS 80 gr A4; \r\nHVS 75 gr ...         2025-01-01
# 6  Ball Liner; \r\nEagle 655; \r\nTrigonal Clip N...         2025-01-01
# 7  Fotocopy Hitam Putih A4/F4; \r\nFotocopy Hitam...         2025-01-01
# 8  BT5000 (Cyan); \r\nBT6000; \r\n---; \r\nBT5000...         2025-01-01
# 9  Rapat Biasa; \r\nRapat Biasa; \r\nRapat Biasa;...         2025-01-01
#
#   tgl_akhir_pemilihan tgl_awal_kontrak tgl_akhir_kontrak tgl_awal_pemanfaatan  \
# 0          2024-12-01       2025-01-01        2025-12-01           2025-01-01
# 1          2025-02-01       2025-02-01        2025-04-01           2025-05-01
# 2          2024-12-01       2025-01-01        2025-12-01           2025-01-01
# 3          2024-12-01       2025-01-01        2025-12-01           2025-01-01
# 4          2024-12-01       2025-01-01        2025-12-01           2025-01-01
# 5          2025-01-01       2025-01-01        2025-12-01           2025-01-01
# 6          2025-01-01       2025-01-01        2025-12-01           2025-01-01
# 7          2025-01-01       2025-01-01        2025-12-01           2025-01-01
# 8          2025-01-01       2025-01-01        2025-12-01           2025-01-01
# 9          2025-01-01       2025-01-01        2025-12-01           2025-01-01
#
#   tgl_akhir_pemanfaatan tgl_buat_paket tgl_pengumuman_paket  \
# 0            2025-12-01     2024-11-22  2024-11-22 22:22:47
# 1            2025-12-01     2024-12-09  2024-12-09 15:52:13
# 2            2025-12-01     2024-12-10  2024-12-16 14:25:38
# 3            2025-12-01     2024-12-10  2024-12-12 17:05:24
# 4            2025-12-01     2024-12-10  2024-12-12 17:05:24
# 5            2025-12-01     2024-12-14  2025-03-07 15:38:40
# 6            2025-12-01     2024-12-14  2025-03-07 15:35:01
# 7            2025-12-01     2024-12-14  2025-03-07 15:33:00
# 8            2025-12-01     2024-12-14  2025-03-07 15:38:40
# 9            2025-12-01     2024-12-14  2025-03-07 15:33:00
#
#               nip_ppk                          nama_ppk        username_ppk  \
# 0  197606132006041012  dr. Batara Hendra Putra Sianipar     batara.ppk24-97
# 1  198006122011011003                ISFANDIAR, ST. MT.  isfandiar.ppk24-97
# 2  196901141998031004               HARDIAN, S.T., M.T.    hardian.ppk24-97
# 3  196901141998031004               HARDIAN, S.T., M.T.    hardian.ppk24-97
# 4  196901141998031004               HARDIAN, S.T., M.T.    hardian.ppk24-97
# 5  197005021999031005           Drs. Ahmad Priyono, MM.    priyono.ppk24-97
# 6  197005021999031005           Drs. Ahmad Priyono, MM.    priyono.ppk24-97
# 7  197005021999031005           Drs. Ahmad Priyono, MM.    priyono.ppk24-97
# 8  197005021999031005           Drs. Ahmad Priyono, MM.    priyono.ppk24-97
# 9  197005021999031005           Drs. Ahmad Priyono, MM.    priyono.ppk24-97
#
#    status_aktif_rup  status_delete_rup status_umumkan_rup  \
# 0              True              False         Terumumkan
# 1              True              False         Terumumkan
# 2              True              False         Terumumkan
# 3              True              False         Terumumkan
# 4              True              False         Terumumkan
# 5              True              False         Terumumkan
# 6              True              False         Terumumkan
# 7              True              False         Terumumkan
# 8              True              False         Terumumkan
# 9              True              False         Terumumkan
#
#    status_dikecualikan alasan_dikecualikan tahun_pertama  \
# 0                False                              None
# 1                False                None          None
# 2                False                None          None
# 3                False                None          None
# 4                False                None          None
# 5                False                None          None
# 6                False                None          None
# 7                False                None          None
# 8                False                None          None
# 9                False                None          None
#
#   kode_rup_tahun_pertama nomor_kontrak  spp_aspek_ekonomi  spp_aspek_sosial  \
# 0                   None          None              False             False
# 1                   None          None              False             False
# 2                   None          None               True              True
# 3                   None          None               True              True
# 4                   None          None               True              True
# 5                   None          None              False             False
# 6                   None          None              False             False
# 7                   None          None              False             False
# 8                   None          None              False             False
# 9                   None          None              False             False
#
#    spp_aspek_lingkungan _event_date
# 0                 False  2025-11-05
# 1                 False  2025-11-05
# 2                  True  2025-11-05
# 3                  True  2025-11-05
# 4                  True  2025-11-05
# 5                 False  2025-11-05
# 6                 False  2025-11-05
# 7                 False  2025-11-05
# 8                 False  2025-11-05
# 9                 False  2025-11-05

# %%
df.tail()
# Out:
#        tahun_anggaran kd_klpd                  nama_klpd jenis_klpd  \
# 16425            2025    D197  Provinsi Kalimantan Barat   PROVINSI
# 16426            2025    D197  Provinsi Kalimantan Barat   PROVINSI
# 16427            2025    D197  Provinsi Kalimantan Barat   PROVINSI
# 16428            2025    D197  Provinsi Kalimantan Barat   PROVINSI
# 16429            2025    D197  Provinsi Kalimantan Barat   PROVINSI
#
#        kd_satker           kd_satker_str  \
# 16425     264467  2.12.2.14.0.00.01.0000
# 16426     264470  2.16.2.20.2.21.01.0000
# 16427     264481  3.27.0.00.0.00.02.0000
# 16428     264481  3.27.0.00.0.00.02.0000
# 16429     264481  3.27.0.00.0.00.02.0000
#
#                                              nama_satker    kd_rup  \
# 16425  DINAS KEPENDUDUKAN DAN PENCATATAN SIPIL PROVIN...  61522231
# 16426  DINAS KOMUNIKASI DAN INFORMATIKA PROVINSI KALI...  61524633
# 16427  DINAS PERKEBUNAN DAN PETERNAKAN PROVINSI KALIM...  61526361
# 16428  DINAS PERKEBUNAN DAN PETERNAKAN PROVINSI KALIM...  61526396
# 16429  DINAS PERKEBUNAN DAN PETERNAKAN PROVINSI KALIM...  61526448
#
#                                               nama_paket       pagu  \
# 16425  Belanja Alat/Bahan untuk Kegiatan Kantor- Baha...     408000
# 16426  Belanja Jasa Konsultansi Berorientasi Layanan-...   20000000
# 16427                      Pengadaan Bantuan Ternak Sapi  278700000
# 16428                      Pengadaan Bantuan Ternak Sapi  194150000
# 16429                      Pengadaan Bantuan Ternak Sapi  769950000
#
#        kd_metode_pengadaan    metode_pengadaan kd_jenis_pengadaan  \
# 16425                    9        E-Purchasing                  1
# 16426                    8  Pengadaan Langsung                  3
# 16427                    9        E-Purchasing                  1
# 16428                    9        E-Purchasing                  1
# 16429                    9        E-Purchasing                  1
#
#         jenis_pengadaan status_pradipa status_pdn status_ukm alasan_non_ukm  \
# 16425            Barang    Non-PraDIPA        PDN        UKM           None
# 16426  Jasa Konsultansi    Non-PraDIPA        PDN        UKM           None
# 16427            Barang    Non-PraDIPA        PDN        UKM           None
# 16428            Barang    Non-PraDIPA        PDN        UKM           None
# 16429            Barang    Non-PraDIPA        PDN        UKM           None
#
#       status_konsolidasi tipe_paket  kd_rup_swakelola kd_rup_lokal  \
# 16425    Non-Konsolidasi   Penyedia               NaN         None
# 16426    Non-Konsolidasi   Penyedia               NaN         None
# 16427    Non-Konsolidasi   Penyedia               NaN         None
# 16428    Non-Konsolidasi   Penyedia               NaN         None
# 16429    Non-Konsolidasi   Penyedia               NaN         None
#
#       volume_pekerjaan                                  urarian_pekerjaan  \
# 16425          1 Paket  Belanja Alat/Bahan untuk Kegiatan Kantor- Baha...
# 16426          1 Paket    Belanja Jasa Konsultansi Berorientasi Layanan;
# 16427          20 ekor                                 Ternak Sapi Potong
# 16428          14 ekor                                bantuan sapi potong
# 16429          55 ekor                                 bantuan sapi poton
#
#                                    spesifikasi_pekerjaan tgl_awal_pemilihan  \
# 16425  Belanja Alat/Bahan untuk Kegiatan Kantor- Baha...         2025-01-01
# 16426  Jasa Konsultansi Berorientasi Layanan (koefisi...         2025-01-01
# 16427                                2 jantan; 18 betina         2025-11-01
# 16428                                1 jantan; 13 betina         2025-11-01
# 16429                                7 jantan; 48 betina         2025-11-01
#
#       tgl_akhir_pemilihan tgl_awal_kontrak tgl_akhir_kontrak  \
# 16425          2025-01-01       2025-01-01        2025-12-01
# 16426          2025-01-01       2025-01-01        2025-12-01
# 16427          2025-11-01       2025-11-01        2025-11-01
# 16428          2025-11-01       2025-11-01        2025-11-01
# 16429          2025-11-01       2025-11-01        2025-11-01
#
#       tgl_awal_pemanfaatan tgl_akhir_pemanfaatan tgl_buat_paket  \
# 16425           2025-01-01            2025-12-01     2025-11-04
# 16426           2025-01-01            2025-12-01     2025-11-04
# 16427           2025-11-01            2025-12-01     2025-11-04
# 16428           2025-11-01            2025-12-01     2025-11-04
# 16429           2025-11-01            2025-12-01     2025-11-04
#
#       tgl_pengumuman_paket             nip_ppk                      nama_ppk  \
# 16425  2025-11-04 16:18:58  196912151989031004  Yohanes Budiman, S.IP., M.Si
# 16426  2025-11-04 19:57:02  197405201993111001    Drs. Marwan Seregar, M.Si.
# 16427  2025-11-04 23:43:59  198209232008031001       Stephanus Ricky, S. Hut
# 16428  2025-11-04 23:43:59  198209232008031001       Stephanus Ricky, S. Hut
# 16429  2025-11-04 23:43:59  198209232008031001       Stephanus Ricky, S. Hut
#
#                   username_ppk  status_aktif_rup  status_delete_rup  \
# 16425  yohanesbudiman.ppk24-97              True              False
# 16426     marwan.ppk24-97-2335              True              False
# 16427       stephanus.ppk24-97              True              False
# 16428       stephanus.ppk24-97              True              False
# 16429       stephanus.ppk24-97              True              False
#
#       status_umumkan_rup  status_dikecualikan alasan_dikecualikan  \
# 16425         Terumumkan                False                None
# 16426         Terumumkan                False                None
# 16427         Terumumkan                False                None
# 16428         Terumumkan                False                None
# 16429         Terumumkan                False                None
#
#       tahun_pertama kode_rup_tahun_pertama nomor_kontrak  spp_aspek_ekonomi  \
# 16425          None                   None          None              False
# 16426          None                   None          None              False
# 16427          None                   None          None              False
# 16428          None                   None          None              False
# 16429          None                   None          None              False
#
#        spp_aspek_sosial  spp_aspek_lingkungan _event_date
# 16425             False                 False  2025-11-05
# 16426             False                 False  2025-11-05
# 16427             False                 False  2025-11-05
# 16428             False                 False  2025-11-05
# 16429             False                 False  2025-11-05

# %% [markdown]
# ## ℹ️ Data Info & Ringkasan Statistik

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16430 entries, 0 to 16429
# Data columns (total 48 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   tahun_anggaran          16430 non-null  int64
#  1   kd_klpd                 16430 non-null  object
#  2   nama_klpd               16430 non-null  object
#  3   jenis_klpd              16430 non-null  object
#  4   kd_satker               16430 non-null  int64
#  5   kd_satker_str           16430 non-null  object
#  6   nama_satker             16430 non-null  object
#  7   kd_rup                  16430 non-null  int64
#  8   nama_paket              16430 non-null  object
#  9   pagu                    16430 non-null  int64
#  10  kd_metode_pengadaan     16430 non-null  int64
#  11  metode_pengadaan        16430 non-null  object
#  12  kd_jenis_pengadaan      16429 non-null  object
#  13  jenis_pengadaan         16429 non-null  object
#  14  status_pradipa          16430 non-null  object
#  15  status_pdn              16430 non-null  object
#  16  status_ukm              16430 non-null  object
#  17  alasan_non_ukm          68 non-null     object
#  18  status_konsolidasi      16430 non-null  object
#  19  tipe_paket              16430 non-null  object
#  20  kd_rup_swakelola        14 non-null     float64
#  21  kd_rup_lokal            0 non-null      object
#  22  volume_pekerjaan        16430 non-null  object
#  23  urarian_pekerjaan       16430 non-null  object
#  24  spesifikasi_pekerjaan   16430 non-null  object
#  25  tgl_awal_pemilihan      16430 non-null  object
#  26  tgl_akhir_pemilihan     16430 non-null  object
#  27  tgl_awal_kontrak        16430 non-null  object
#  28  tgl_akhir_kontrak       16430 non-null  object
#  29  tgl_awal_pemanfaatan    16430 non-null  object
#  30  tgl_akhir_pemanfaatan   16430 non-null  object
#  31  tgl_buat_paket          16430 non-null  object
#  32  tgl_pengumuman_paket    16430 non-null  datetime64[us]
#  33  nip_ppk                 16391 non-null  object
#  34  nama_ppk                16391 non-null  object
#  35  username_ppk            16391 non-null  object
#  36  status_aktif_rup        16430 non-null  bool
#  37  status_delete_rup       16430 non-null  bool
#  38  status_umumkan_rup      16430 non-null  object
#  39  status_dikecualikan     16430 non-null  bool
#  40  alasan_dikecualikan     318 non-null    object
#  41  tahun_pertama           0 non-null      object
#  42  kode_rup_tahun_pertama  0 non-null      object
#  43  nomor_kontrak           0 non-null      object
#  44  spp_aspek_ekonomi       16430 non-null  bool
#  45  spp_aspek_sosial        16430 non-null  bool
#  46  spp_aspek_lingkungan    16430 non-null  bool
#  47  _event_date             16430 non-null  object
# dtypes: bool(6), datetime64[us](1), float64(1), int64(5), object(35)
# memory usage: 5.4+ MB

# %%
df.describe()
# Out:
#        tahun_anggaran  kd_satker      kd_rup           pagu  \
# count        16430.00   16430.00    16430.00       16430.00
# mean          2025.00  233311.01 58084327.33   128525019.61
# min           2025.00   64173.00 53540979.00           1.00
# 25%           2025.00  264449.00 56399054.25     1360000.00
# 50%           2025.00  264464.00 58490153.00     8354500.00
# 75%           2025.00  264488.00 59359089.50    91734075.00
# max           2025.00  380858.00 61526448.00 74802424962.00
# std              0.00   67216.37  2151406.79  1217381191.99
#
#        kd_metode_pengadaan  kd_rup_swakelola        tgl_pengumuman_paket
# count             16430.00             14.00                       16430
# mean                  8.97       40382347.29  2025-04-28 04:16:46.248448
# min                   7.00       40382253.00         2024-11-22 22:22:47
# 25%                   8.00       40382289.00         2025-02-23 17:49:57
# 50%                   9.00       40382335.00         2025-03-25 21:44:45
# 75%                   9.00       40382412.00  2025-05-19 23:23:52.750000
# max                  16.00       40382457.00         2025-11-04 23:43:59
# std                   1.39             76.62                         NaN

# %%
df.describe(include='all')
# Out:
#         tahun_anggaran kd_klpd                  nama_klpd jenis_klpd  \
# count         16430.00   16430                      16430      16430
# unique             NaN       1                          1          1
# top                NaN    D197  Provinsi Kalimantan Barat   PROVINSI
# freq               NaN   16430                      16430      16430
# mean           2025.00     NaN                        NaN        NaN
# min            2025.00     NaN                        NaN        NaN
# 25%            2025.00     NaN                        NaN        NaN
# 50%            2025.00     NaN                        NaN        NaN
# 75%            2025.00     NaN                        NaN        NaN
# max            2025.00     NaN                        NaN        NaN
# std               0.00     NaN                        NaN        NaN
#
#         kd_satker           kd_satker_str  \
# count    16430.00                   16430
# unique        NaN                      88
# top           NaN  1.03.0.00.0.00.01.0000
# freq          NaN                    2428
# mean    233311.01                     NaN
# min      64173.00                     NaN
# 25%     264449.00                     NaN
# 50%     264464.00                     NaN
# 75%     264488.00                     NaN
# max     380858.00                     NaN
# std      67216.37                     NaN
#
#                                               nama_satker      kd_rup  \
# count                                               16430    16430.00
# unique                                                 88         NaN
# top     DINAS PEKERJAAN UMUM DAN PENATAAN RUANG PROVIN...         NaN
# freq                                                 2428         NaN
# mean                                                  NaN 58084327.33
# min                                                   NaN 53540979.00
# 25%                                                   NaN 56399054.25
# 50%                                                   NaN 58490153.00
# 75%                                                   NaN 59359089.50
# max                                                   NaN 61526448.00
# std                                                   NaN  2151406.79
#
#                                                nama_paket           pagu  \
# count                                               16430       16430.00
# unique                                               7785            NaN
# top     Belanja Alat/Bahan untuk Kegiatan Kantor- Kert...            NaN
# freq                                                 1181            NaN
# mean                                                  NaN   128525019.61
# min                                                   NaN           1.00
# 25%                                                   NaN     1360000.00
# 50%                                                   NaN     8354500.00
# 75%                                                   NaN    91734075.00
# max                                                   NaN 74802424962.00
# std                                                   NaN  1217381191.99
#
#         kd_metode_pengadaan metode_pengadaan kd_jenis_pengadaan  \
# count              16430.00            16430              16429
# unique                  NaN                8                  5
# top                     NaN     E-Purchasing                  1
# freq                    NaN            11245              10530
# mean                   8.97              NaN                NaN
# min                    7.00              NaN                NaN
# 25%                    8.00              NaN                NaN
# 50%                    9.00              NaN                NaN
# 75%                    9.00              NaN                NaN
# max                   16.00              NaN                NaN
# std                    1.39              NaN                NaN
#
#        jenis_pengadaan status_pradipa status_pdn status_ukm  \
# count            16429          16430      16430      16430
# unique               5              2          2          2
# top             Barang    Non-PraDIPA        PDN        UKM
# freq             10530          16329      16397      16372
# mean               NaN            NaN        NaN        NaN
# min                NaN            NaN        NaN        NaN
# 25%                NaN            NaN        NaN        NaN
# 50%                NaN            NaN        NaN        NaN
# 75%                NaN            NaN        NaN        NaN
# max                NaN            NaN        NaN        NaN
# std                NaN            NaN        NaN        NaN
#
#                                     alasan_non_ukm status_konsolidasi  \
# count                                           68              16430
# unique                                           3                  2
# top     Kompetensi tidak sesuai dengan usaha kecil    Non-Konsolidasi
# freq                                            39              16382
# mean                                           NaN                NaN
# min                                            NaN                NaN
# 25%                                            NaN                NaN
# 50%                                            NaN                NaN
# 75%                                            NaN                NaN
# max                                            NaN                NaN
# std                                            NaN                NaN
#
#        tipe_paket  kd_rup_swakelola kd_rup_lokal volume_pekerjaan  \
# count       16430             14.00            0            16430
# unique          2               NaN            0              960
# top      Penyedia               NaN          NaN          1 Paket
# freq        16416               NaN          NaN            11387
# mean          NaN       40382347.29          NaN              NaN
# min           NaN       40382253.00          NaN              NaN
# 25%           NaN       40382289.00          NaN              NaN
# 50%           NaN       40382335.00          NaN              NaN
# 75%           NaN       40382412.00          NaN              NaN
# max           NaN       40382457.00          NaN              NaN
# std           NaN             76.62          NaN              NaN
#
#                                         urarian_pekerjaan  \
# count                                               16430
# unique                                               7723
# top     Persediaan Untuk Dijual/Diserahkan Kepada Masy...
# freq                                                  531
# mean                                                  NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
# std                                                   NaN
#
#                      spesifikasi_pekerjaan tgl_awal_pemilihan  \
# count                                16430              16430
# unique                                8283                 27
# top     Rapat Biasa; \r\nRapat Biasa; \r\n         2025-01-01
# freq                                   593               7393
# mean                                   NaN                NaN
# min                                    NaN                NaN
# 25%                                    NaN                NaN
# 50%                                    NaN                NaN
# 75%                                    NaN                NaN
# max                                    NaN                NaN
# std                                    NaN                NaN
#
#        tgl_akhir_pemilihan tgl_awal_kontrak tgl_akhir_kontrak  \
# count                16430            16430             16430
# unique                  24               23                22
# top             2025-01-01       2025-01-01        2025-12-01
# freq                  6694             6334              8010
# mean                   NaN              NaN               NaN
# min                    NaN              NaN               NaN
# 25%                    NaN              NaN               NaN
# 50%                    NaN              NaN               NaN
# 75%                    NaN              NaN               NaN
# max                    NaN              NaN               NaN
# std                    NaN              NaN               NaN
#
#        tgl_awal_pemanfaatan tgl_akhir_pemanfaatan tgl_buat_paket  \
# count                 16430                 16430          16430
# unique                   23                    30            248
# top              2025-01-01            2025-12-01     2025-03-19
# freq                   6763                 14146            548
# mean                    NaN                   NaN            NaN
# min                     NaN                   NaN            NaN
# 25%                     NaN                   NaN            NaN
# 50%                     NaN                   NaN            NaN
# 75%                     NaN                   NaN            NaN
# max                     NaN                   NaN            NaN
# std                     NaN                   NaN            NaN
#
#               tgl_pengumuman_paket             nip_ppk      nama_ppk  \
# count                        16430               16391         16391
# unique                         NaN                 101           104
# top                            NaN  198006032009031004  Gerry Candra
# freq                           NaN                1986          1986
# mean    2025-04-28 04:16:46.248448                 NaN           NaN
# min            2024-11-22 22:22:47                 NaN           NaN
# 25%            2025-02-23 17:49:57                 NaN           NaN
# 50%            2025-03-25 21:44:45                 NaN           NaN
# 75%     2025-05-19 23:23:52.750000                 NaN           NaN
# max            2025-11-04 23:43:59                 NaN           NaN
# std                            NaN                 NaN           NaN
#
#                username_ppk status_aktif_rup status_delete_rup  \
# count                 16391            16430             16430
# unique                  105                1                 1
# top     gerry.ppk24-97-9815             True             False
# freq                   1986            16430             16430
# mean                    NaN              NaN               NaN
# min                     NaN              NaN               NaN
# 25%                     NaN              NaN               NaN
# 50%                     NaN              NaN               NaN
# 75%                     NaN              NaN               NaN
# max                     NaN              NaN               NaN
# std                     NaN              NaN               NaN
#
#        status_umumkan_rup status_dikecualikan alasan_dikecualikan  \
# count               16430               16430                 318
# unique                  1                   2                  15
# top            Terumumkan               False
# freq                16430               15933                 202
# mean                  NaN                 NaN                 NaN
# min                   NaN                 NaN                 NaN
# 25%                   NaN                 NaN                 NaN
# 50%                   NaN                 NaN                 NaN
# 75%                   NaN                 NaN                 NaN
# max                   NaN                 NaN                 NaN
# std                   NaN                 NaN                 NaN
#
#        tahun_pertama kode_rup_tahun_pertama nomor_kontrak spp_aspek_ekonomi  \
# count              0                      0             0             16430
# unique             0                      0             0                 2
# top              NaN                    NaN           NaN             False
# freq             NaN                    NaN           NaN             13330
# mean             NaN                    NaN           NaN               NaN
# min              NaN                    NaN           NaN               NaN
# 25%              NaN                    NaN           NaN               NaN
# 50%              NaN                    NaN           NaN               NaN
# 75%              NaN                    NaN           NaN               NaN
# max              NaN                    NaN           NaN               NaN
# std              NaN                    NaN           NaN               NaN
#
#        spp_aspek_sosial spp_aspek_lingkungan _event_date
# count             16430                16430       16430
# unique                2                    2           1
# top               False                False  2025-11-05
# freq              13784                13161       16430
# mean                NaN                  NaN         NaN
# min                 NaN                  NaN         NaN
# 25%                 NaN                  NaN         NaN
# 50%                 NaN                  NaN         NaN
# 75%                 NaN                  NaN         NaN
# max                 NaN                  NaN         NaN
# std                 NaN                  NaN         NaN

# %% [markdown]
# ## 📚 Kolom Penting

# %%
all_columns = df.columns.tolist()
print(f"Total columns: {len(all_columns)}")
print(all_columns)

key_columns = [
    'kd_rup', 'nama_paket', 'pagu', 'metode_pengadaan', 'jenis_pengadaan',
    'nama_klpd', 'nama_satker', 'status_pdn', 'status_ukm',
    'tgl_pengumuman_paket'
]
print("Kolom penting untuk analisis awal:")
for col in key_columns:
    print(f"- {col}")
# Out:
# Total columns: 48
# ['tahun_anggaran', 'kd_klpd', 'nama_klpd', 'jenis_klpd', 'kd_satker', 'kd_satker_str', 'nama_satker', 'kd_rup', 'nama_paket', 'pagu', 'kd_metode_pengadaan', 'metode_pengadaan', 'kd_jenis_pengadaan', 'jenis_pengadaan', 'status_pradipa', 'status_pdn', 'status_ukm', 'alasan_non_ukm', 'status_konsolidasi', 'tipe_paket', 'kd_rup_swakelola', 'kd_rup_lokal', 'volume_pekerjaan', 'urarian_pekerjaan', 'spesifikasi_pekerjaan', 'tgl_awal_pemilihan', 'tgl_akhir_pemilihan', 'tgl_awal_kontrak', 'tgl_akhir_kontrak', 'tgl_awal_pemanfaatan', 'tgl_akhir_pemanfaatan', 'tgl_buat_paket', 'tgl_pengumuman_paket', 'nip_ppk', 'nama_ppk', 'username_ppk', 'status_aktif_rup', 'status_delete_rup', 'status_umumkan_rup', 'status_dikecualikan', 'alasan_dikecualikan', 'tahun_pertama', 'kode_rup_tahun_pertama', 'nomor_kontrak', 'spp_aspek_ekonomi', 'spp_aspek_sosial', 'spp_aspek_lingkungan', '_event_date']
# Kolom penting untuk analisis awal:
# - kd_rup
# - nama_paket
# - pagu
# - metode_pengadaan
# - jenis_pengadaan
# - nama_klpd
# - nama_satker
# - status_pdn
# - status_ukm
# - tgl_pengumuman_paket

# %% [markdown]
# ## 🧩 Selecting Columns

# %%
nama_paket_series = df['nama_paket']
subset_df = df[['nama_paket', 'pagu', 'metode_pengadaan']]
subset_df.head()
# Out:
#                                           nama_paket        pagu  \
# 0           Belanja Bahan Makanan dan Minuman Pasien  7700000000
# 1  Perencanaan Rehabilitasi Gedung UPT Pengujian ...   300000000
# 2  PENGAWASAN TEKNIS PENGGANTIAN/PEMBANGUNAN JEMB...  1200000000
# 3  PENGAWASAN TEKNIS PENINGKATAN JALAN TANJUNG  M...  1200000000
# 4  PENGAWASAN TEKNIS PENINGKATAN JALAN MARAU  AIR...  1500000000
#
#   metode_pengadaan
# 0           Tender
# 1          Seleksi
# 2          Seleksi
# 3          Seleksi
# 4          Seleksi

# %% [markdown]
# ## 🔎 Seleksi Baris dengan `.loc`

# %%
first_rows = df.loc[0:4, ['nama_paket', 'pagu', 'metode_pengadaan']]
high_value_loc = df.loc[df['pagu'] > 1_000_000_000, ['nama_paket', 'pagu']].head()
first_rows
# Out:
#                                           nama_paket        pagu  \
# 0           Belanja Bahan Makanan dan Minuman Pasien  7700000000
# 1  Perencanaan Rehabilitasi Gedung UPT Pengujian ...   300000000
# 2  PENGAWASAN TEKNIS PENGGANTIAN/PEMBANGUNAN JEMB...  1200000000
# 3  PENGAWASAN TEKNIS PENINGKATAN JALAN TANJUNG  M...  1200000000
# 4  PENGAWASAN TEKNIS PENINGKATAN JALAN MARAU  AIR...  1500000000
#
#   metode_pengadaan
# 0           Tender
# 1          Seleksi
# 2          Seleksi
# 3          Seleksi
# 4          Seleksi

# %% [markdown]
# ## 🔢 Seleksi Baris dengan `.iloc`

# %%
iloc_sample = df.iloc[0:5, [0, 1, 2]]
last_rows_iloc = df.iloc[-5:]
iloc_sample
# Out:
#    tahun_anggaran kd_klpd                  nama_klpd
# 0            2025    D197  Provinsi Kalimantan Barat
# 1            2025    D197  Provinsi Kalimantan Barat
# 2            2025    D197  Provinsi Kalimantan Barat
# 3            2025    D197  Provinsi Kalimantan Barat
# 4            2025    D197  Provinsi Kalimantan Barat

# %% [markdown]
# ## 🎣 Boolean Indexing

# %%
high_value_packages = df[df['pagu'] > 1_000_000_000]
tender_only = df[df['metode_pengadaan'] == 'Tender']
combined_filter = df[(df['pagu'] > 1_000_000_000) & (df['metode_pengadaan'] == 'Tender')]

print(f"Paket dengan pagu > 1M: {len(high_value_packages):,}")
print(f"Paket tender saja: {len(tender_only):,}")
print(f"Paket tender & pagu > 1M: {len(combined_filter):,}")
combined_filter.head()
# Out:
# Paket dengan pagu > 1M: 181
# Paket tender saja: 77
# Paket tender & pagu > 1M: 67
#       tahun_anggaran kd_klpd                  nama_klpd jenis_klpd  kd_satker  \
# 0               2025    D197  Provinsi Kalimantan Barat   PROVINSI     264455
# 3681            2025    D197  Provinsi Kalimantan Barat   PROVINSI     309157
# 3682            2025    D197  Provinsi Kalimantan Barat   PROVINSI     309157
# 3688            2025    D197  Provinsi Kalimantan Barat   PROVINSI     309157
# 3691            2025    D197  Provinsi Kalimantan Barat   PROVINSI     309157
#
#                kd_satker_str                                 nama_satker  \
# 0     1.02.0.00.0.00.03.0000  RUMAH SAKIT JIWA PROVINSI KALIMANTAN BARAT
# 3681  1.02.0.00.0.00.01.0005     RUMAH SAKIT UMUM DAERAH DOKTER SOEDARSO
# 3682  1.02.0.00.0.00.01.0005     RUMAH SAKIT UMUM DAERAH DOKTER SOEDARSO
# 3688  1.02.0.00.0.00.01.0005     RUMAH SAKIT UMUM DAERAH DOKTER SOEDARSO
# 3691  1.02.0.00.0.00.01.0005     RUMAH SAKIT UMUM DAERAH DOKTER SOEDARSO
#
#         kd_rup                                         nama_paket  \
# 0     53540979           Belanja Bahan Makanan dan Minuman Pasien
# 3681  56095890  Belanja Modal Bangunan Kesehatan - Bangunan Un...
# 3682  56096857  Belanja Modal Bangunan Kesehatan - Gudang Farm...
# 3688  56104080  Belanja Modal Bangunan Kesehatan - Pembangunan...
# 3691  56104734  Belanja Modal Bangunan Kesehatan - Renovasi Ge...
#
#              pagu  kd_metode_pengadaan metode_pengadaan kd_jenis_pengadaan  \
# 0      7700000000                   13           Tender                  1
# 3681   2155830000                   13           Tender                  2
# 3682   3822403000                   13           Tender                  2
# 3688  32451362000                   13           Tender                  2
# 3691   2303891000                   13           Tender                  2
#
#            jenis_pengadaan status_pradipa status_pdn status_ukm  \
# 0                   Barang        PraDIPA        PDN        UKM
# 3681  Pekerjaan Konstruksi    Non-PraDIPA        PDN        UKM
# 3682  Pekerjaan Konstruksi    Non-PraDIPA        PDN        UKM
# 3688  Pekerjaan Konstruksi    Non-PraDIPA        PDN        UKM
# 3691  Pekerjaan Konstruksi    Non-PraDIPA        PDN        UKM
#
#      alasan_non_ukm status_konsolidasi tipe_paket  kd_rup_swakelola  \
# 0              None    Non-Konsolidasi   Penyedia               NaN
# 3681           None    Non-Konsolidasi   Penyedia               NaN
# 3682           None    Non-Konsolidasi   Penyedia               NaN
# 3688           None    Non-Konsolidasi   Penyedia               NaN
# 3691           None    Non-Konsolidasi   Penyedia               NaN
#
#      kd_rup_lokal volume_pekerjaan  \
# 0            None          1 paket
# 3681         None          1 Paket
# 3682         None          1 Paket
# 3688         None          1 Paket
# 3691         None          1 Paket
#
#                                       urarian_pekerjaan  \
# 0              Belanja Bahan Makanan dan Minuman Pasien
# 3681  Sederhana (Jumlah lantai\r\nsampai dengan 2 (dua)
# 3682  Sederhana (Jumlah lantai sampai dengan 2 (dua)...
# 3688  Sederhana (Jumlah lantai sampai dengan 2 (dua)...
# 3691           Klasifikasi : Sederhana (Rusak\r\nBerat)
#
#                                   spesifikasi_pekerjaan tgl_awal_pemilihan  \
# 0              Belanja Bahan Makanan dan Minuman Pasien         2024-11-01
# 3681  Sederhana (Jumlah lantai\r\nsampai dengan 2 (dua)         2025-06-01
# 3682  Sederhana (Jumlah lantai sampai dengan 2 (dua)...         2025-06-01
# 3688  Sederhana (Jumlah lantai sampai dengan 2 (dua)...         2025-05-01
# 3691           Klasifikasi : Sederhana (Rusak\r\nBerat)         2025-06-01
#
#      tgl_akhir_pemilihan tgl_awal_kontrak tgl_akhir_kontrak  \
# 0             2024-12-01       2025-01-01        2025-12-01
# 3681          2025-07-01       2025-07-01        2025-11-01
# 3682          2025-07-01       2025-07-01        2025-11-01
# 3688          2025-06-01       2025-06-01        2025-12-01
# 3691          2025-07-01       2025-07-01        2025-11-01
#
#      tgl_awal_pemanfaatan tgl_akhir_pemanfaatan tgl_buat_paket  \
# 0              2025-01-01            2025-12-01     2024-11-22
# 3681           2025-12-01            2025-12-01     2025-03-12
# 3682           2025-11-01            2025-12-01     2025-03-12
# 3688           2025-12-01            2025-12-01     2025-03-12
# 3691           2025-11-01            2025-12-01     2025-03-12
#
#      tgl_pengumuman_paket             nip_ppk  \
# 0     2024-11-22 22:22:47  197606132006041012
# 3681  2025-03-12 16:04:38  197006271991031006
# 3682  2025-03-12 16:04:38  197006271991031006
# 3688  2025-03-12 16:04:38  197006271991031006
# 3691  2025-03-12 16:04:38  197006271991031006
#
#                               nama_ppk       username_ppk  status_aktif_rup  \
# 0     dr. Batara Hendra Putra Sianipar    batara.ppk24-97              True
# 3681      Ari Mursetyo, S.Si.T,, M.P.H  mursetyo.ppk24-97              True
# 3682      Ari Mursetyo, S.Si.T,, M.P.H  mursetyo.ppk24-97              True
# 3688      Ari Mursetyo, S.Si.T,, M.P.H  mursetyo.ppk24-97              True
# 3691      Ari Mursetyo, S.Si.T,, M.P.H  mursetyo.ppk24-97              True
#
#       status_delete_rup status_umumkan_rup  status_dikecualikan  \
# 0                 False         Terumumkan                False
# 3681              False         Terumumkan                False
# 3682              False         Terumumkan                False
# 3688              False         Terumumkan                False
# 3691              False         Terumumkan                False
#
#      alasan_dikecualikan tahun_pertama kode_rup_tahun_pertama nomor_kontrak  \
# 0                                 None                   None          None
# 3681                              None                   None          None
# 3682                              None                   None          None
# 3688                              None                   None          None
# 3691                              None                   None          None
#
#       spp_aspek_ekonomi  spp_aspek_sosial  spp_aspek_lingkungan _event_date
# 0                 False             False                 False  2025-11-05
# 3681              False             False                 False  2025-11-05
# 3682              False             False                 False  2025-11-05
# 3688              False             False                 False  2025-11-05
# 3691              False             False                 False  2025-11-05

# %% [markdown]
# ## 🧮 Query Method

# %%
threshold = 1_000_000_000
query_result = df.query('pagu > @threshold and metode_pengadaan == "Tender"')
contains_pengadaan = df.query('nama_paket.str.contains("Pengadaan", case=False)', engine='python')
query_result.head()
# Out:
#       tahun_anggaran kd_klpd                  nama_klpd jenis_klpd  kd_satker  \
# 0               2025    D197  Provinsi Kalimantan Barat   PROVINSI     264455
# 3681            2025    D197  Provinsi Kalimantan Barat   PROVINSI     309157
# 3682            2025    D197  Provinsi Kalimantan Barat   PROVINSI     309157
# 3688            2025    D197  Provinsi Kalimantan Barat   PROVINSI     309157
# 3691            2025    D197  Provinsi Kalimantan Barat   PROVINSI     309157
#
#                kd_satker_str                                 nama_satker  \
# 0     1.02.0.00.0.00.03.0000  RUMAH SAKIT JIWA PROVINSI KALIMANTAN BARAT
# 3681  1.02.0.00.0.00.01.0005     RUMAH SAKIT UMUM DAERAH DOKTER SOEDARSO
# 3682  1.02.0.00.0.00.01.0005     RUMAH SAKIT UMUM DAERAH DOKTER SOEDARSO
# 3688  1.02.0.00.0.00.01.0005     RUMAH SAKIT UMUM DAERAH DOKTER SOEDARSO
# 3691  1.02.0.00.0.00.01.0005     RUMAH SAKIT UMUM DAERAH DOKTER SOEDARSO
#
#         kd_rup                                         nama_paket  \
# 0     53540979           Belanja Bahan Makanan dan Minuman Pasien
# 3681  56095890  Belanja Modal Bangunan Kesehatan - Bangunan Un...
# 3682  56096857  Belanja Modal Bangunan Kesehatan - Gudang Farm...
# 3688  56104080  Belanja Modal Bangunan Kesehatan - Pembangunan...
# 3691  56104734  Belanja Modal Bangunan Kesehatan - Renovasi Ge...
#
#              pagu  kd_metode_pengadaan metode_pengadaan kd_jenis_pengadaan  \
# 0      7700000000                   13           Tender                  1
# 3681   2155830000                   13           Tender                  2
# 3682   3822403000                   13           Tender                  2
# 3688  32451362000                   13           Tender                  2
# 3691   2303891000                   13           Tender                  2
#
#            jenis_pengadaan status_pradipa status_pdn status_ukm  \
# 0                   Barang        PraDIPA        PDN        UKM
# 3681  Pekerjaan Konstruksi    Non-PraDIPA        PDN        UKM
# 3682  Pekerjaan Konstruksi    Non-PraDIPA        PDN        UKM
# 3688  Pekerjaan Konstruksi    Non-PraDIPA        PDN        UKM
# 3691  Pekerjaan Konstruksi    Non-PraDIPA        PDN        UKM
#
#      alasan_non_ukm status_konsolidasi tipe_paket  kd_rup_swakelola  \
# 0              None    Non-Konsolidasi   Penyedia               NaN
# 3681           None    Non-Konsolidasi   Penyedia               NaN
# 3682           None    Non-Konsolidasi   Penyedia               NaN
# 3688           None    Non-Konsolidasi   Penyedia               NaN
# 3691           None    Non-Konsolidasi   Penyedia               NaN
#
#      kd_rup_lokal volume_pekerjaan  \
# 0            None          1 paket
# 3681         None          1 Paket
# 3682         None          1 Paket
# 3688         None          1 Paket
# 3691         None          1 Paket
#
#                                       urarian_pekerjaan  \
# 0              Belanja Bahan Makanan dan Minuman Pasien
# 3681  Sederhana (Jumlah lantai\r\nsampai dengan 2 (dua)
# 3682  Sederhana (Jumlah lantai sampai dengan 2 (dua)...
# 3688  Sederhana (Jumlah lantai sampai dengan 2 (dua)...
# 3691           Klasifikasi : Sederhana (Rusak\r\nBerat)
#
#                                   spesifikasi_pekerjaan tgl_awal_pemilihan  \
# 0              Belanja Bahan Makanan dan Minuman Pasien         2024-11-01
# 3681  Sederhana (Jumlah lantai\r\nsampai dengan 2 (dua)         2025-06-01
# 3682  Sederhana (Jumlah lantai sampai dengan 2 (dua)...         2025-06-01
# 3688  Sederhana (Jumlah lantai sampai dengan 2 (dua)...         2025-05-01
# 3691           Klasifikasi : Sederhana (Rusak\r\nBerat)         2025-06-01
#
#      tgl_akhir_pemilihan tgl_awal_kontrak tgl_akhir_kontrak  \
# 0             2024-12-01       2025-01-01        2025-12-01
# 3681          2025-07-01       2025-07-01        2025-11-01
# 3682          2025-07-01       2025-07-01        2025-11-01
# 3688          2025-06-01       2025-06-01        2025-12-01
# 3691          2025-07-01       2025-07-01        2025-11-01
#
#      tgl_awal_pemanfaatan tgl_akhir_pemanfaatan tgl_buat_paket  \
# 0              2025-01-01            2025-12-01     2024-11-22
# 3681           2025-12-01            2025-12-01     2025-03-12
# 3682           2025-11-01            2025-12-01     2025-03-12
# 3688           2025-12-01            2025-12-01     2025-03-12
# 3691           2025-11-01            2025-12-01     2025-03-12
#
#      tgl_pengumuman_paket             nip_ppk  \
# 0     2024-11-22 22:22:47  197606132006041012
# 3681  2025-03-12 16:04:38  197006271991031006
# 3682  2025-03-12 16:04:38  197006271991031006
# 3688  2025-03-12 16:04:38  197006271991031006
# 3691  2025-03-12 16:04:38  197006271991031006
#
#                               nama_ppk       username_ppk  status_aktif_rup  \
# 0     dr. Batara Hendra Putra Sianipar    batara.ppk24-97              True
# 3681      Ari Mursetyo, S.Si.T,, M.P.H  mursetyo.ppk24-97              True
# 3682      Ari Mursetyo, S.Si.T,, M.P.H  mursetyo.ppk24-97              True
# 3688      Ari Mursetyo, S.Si.T,, M.P.H  mursetyo.ppk24-97              True
# 3691      Ari Mursetyo, S.Si.T,, M.P.H  mursetyo.ppk24-97              True
#
#       status_delete_rup status_umumkan_rup  status_dikecualikan  \
# 0                 False         Terumumkan                False
# 3681              False         Terumumkan                False
# 3682              False         Terumumkan                False
# 3688              False         Terumumkan                False
# 3691              False         Terumumkan                False
#
#      alasan_dikecualikan tahun_pertama kode_rup_tahun_pertama nomor_kontrak  \
# 0                                 None                   None          None
# 3681                              None                   None          None
# 3682                              None                   None          None
# 3688                              None                   None          None
# 3691                              None                   None          None
#
#       spp_aspek_ekonomi  spp_aspek_sosial  spp_aspek_lingkungan _event_date
# 0                 False             False                 False  2025-11-05
# 3681              False             False                 False  2025-11-05
# 3682              False             False                 False  2025-11-05
# 3688              False             False                 False  2025-11-05
# 3691              False             False                 False  2025-11-05

# %% [markdown]
# ## 📊 GroupBy Dasar

# %%
pagu_per_metode = df.groupby('metode_pengadaan')['pagu'].sum().sort_values(ascending=False)
pagu_per_metode / 1_000_000_000
# Out:
# metode_pengadaan
# Pengadaan Langsung    706.99
# E-Purchasing          644.44
# Tender                569.15
# Dikecualikan          148.14
# Seleksi                32.41
# Penunjukan Langsung     7.20
# Tender Cepat            3.33
# Kontes                  0.00
# Name: pagu, dtype: float64

# %% [markdown]
# ## 📈 GroupBy dengan Multiple Aggregations

# %%
agg_result = (
    df.groupby('metode_pengadaan')['pagu']
    .agg(['count', 'sum', 'mean', 'median', 'min', 'max'])
    .sort_values('sum', ascending=False)
)
agg_result
# Out:
#                      count           sum          mean        median  \
# metode_pengadaan
# Pengadaan Langsung    4515  706994610990  156587953.71  180000000.00
# E-Purchasing         11245  644444464651   57309423.27    2720000.00
# Tender                  77  569147597582 7391527241.32 3170000000.00
# Dikecualikan           497  148135925757  298060212.79    9620000.00
# Seleksi                 44   32411774371  736631235.70  800000000.00
# Penunjukan Langsung     48    7201474767  150030724.31   38755000.00
# Tender Cepat             3    3328240000 1109413333.33  767040000.00
# Kontes                   1       1984000    1984000.00    1984000.00
#
#                            min          max
# metode_pengadaan
# Pengadaan Langsung       22000  23634000000
# E-Purchasing                 1  55565778076
# Tender                18380000  37000000000
# Dikecualikan             50000  74802424962
# Seleksi              172500000   1800000000
# Penunjukan Langsung    1000000   1500000000
# Tender Cepat         613200000   1948000000
# Kontes                 1984000      1984000

# %% [markdown]
# ## 🧱 GroupBy Multi Kolom & Rename

# %%
metode_jenis_summary = (
    df.groupby(['metode_pengadaan', 'jenis_pengadaan'])['pagu']
    .agg(['count', 'sum', 'mean'])
    .round(2)
    .reset_index()
)
metode_jenis_summary.columns = [
    'Metode', 'Jenis', 'Jumlah_Paket', 'Total_Pagu', 'Rata_Rata_Pagu'
]
metode_jenis_summary.head(10)
# Out:
#                Metode                 Jenis  Jumlah_Paket    Total_Pagu  \
# 0        Dikecualikan                Barang           234  125347636402
# 1        Dikecualikan          Jasa Lainnya           263   22788289355
# 2        E-Purchasing                Barang          9983  507550552891
# 3        E-Purchasing         Barang;Barang             1      41500000
# 4        E-Purchasing      Jasa Konsultansi            31     930857366
# 5        E-Purchasing          Jasa Lainnya          1183  129190229383
# 6        E-Purchasing  Pekerjaan Konstruksi            46    6730692511
# 7              Kontes                Barang             1       1984000
# 8  Pengadaan Langsung                Barang           297   22407608739
# 9  Pengadaan Langsung      Jasa Konsultansi          1237   76134399437
#
#    Rata_Rata_Pagu
# 0    535673659.84
# 1     86647488.04
# 2     50841485.81
# 3     41500000.00
# 4     30027656.97
# 5    109205603.87
# 6    146319402.41
# 7      1984000.00
# 8     75446494.07
# 9     61547614.74

# %% [markdown]
# ## 🏆 Top 10 Satker dengan Pagu Terbesar

# %%
top_satker = (
    df.groupby('nama_satker')['pagu']
    .sum()
    .sort_values(ascending=False)
    .head(10)
    .reset_index()
)
top_satker['Total_Pagu_Miliar'] = (top_satker['pagu'] / 1_000_000_000).round(2)
top_satker
# Out:
#                                          nama_satker          pagu  \
# 0  DINAS PEKERJAAN UMUM DAN PENATAAN RUANG PROVIN...  841492369155
# 1            RUMAH SAKIT UMUM DAERAH DOKTER SOEDARSO  331063820430
# 2      DINAS PERUMAHAN RAKYAT DAN KAWASAN PERMUKIMAN  282709739900
# 3  DINAS PENDIDIKAN DAN KEBUDAYAAN PROVINSI KALIM...  203875269731
# 4  SEKRETARIAT DEWAN PERWAKILAN RAKYAT DAERAH PRO...   71445025587
# 5                 SEKRETARIAT DAERAH PROVINSI KALBAR   48242938910
# 6         RUMAH SAKIT JIWA PROVINSI KALIMANTAN BARAT   43546134778
# 7  DINAS TANAMAN PANGAN DAN HORTIKULTURA PROVINSI...   23941927599
# 8          DINAS KESEHATAN PROVINSI KALIMANTAN BARAT   17933054839
# 9  BADAN KEUANGAN DAN ASET DAERAH PROVINSI KALIMA...   15665976555
#
#    Total_Pagu_Miliar
# 0             841.49
# 1             331.06
# 2             282.71
# 3             203.88
# 4              71.45
# 5              48.24
# 6              43.55
# 7              23.94
# 8              17.93
# 9              15.67

# %% [markdown]
# ## 🗂️ Sorting Data

# %%
top_by_pagu = df.sort_values('pagu', ascending=False).head(10)
sorted_metode_pagu = df.sort_values(['metode_pengadaan', 'pagu'], ascending=[True, False]).head(10)
top_by_pagu[['nama_paket', 'pagu', 'metode_pengadaan']]
# Out:
#                                               nama_paket         pagu  \
# 8245            Belanja Barang dan Jasa BOSP-BOS Reguler  74802424962
# 15918             Belanja Obat-Obatan-Obat - Obat-obatan  55565778076
# 9232                 PENINGKATAN JALAN SAYAN - KOTA BARU  37000000000
# 15919  Belanja Obat-Obatan-Obat-Obatan Lainnya - Baha...  34239274690
# 3688   Belanja Modal Bangunan Kesehatan - Pembangunan...  32451362000
# 10519       PENINGKATAN JALAN SIMPANG MEDANG - NANGA MAU  30000000000
# 10515         PENINGKATAN JALAN BATAS KOTA SAMBAS  SUBAH  26000000000
# 9237                   PENINGKATAN JALAN MARAU  AIR UPAS  26000000000
# 10526            PENINGKATAN JALAN PESAGUAN  KENDAWANGAN  26000000000
# 9221           PENINGKATAN JALAN SUKADANA - TELUK BATANG  26000000000
#
#       metode_pengadaan
# 8245      Dikecualikan
# 15918     E-Purchasing
# 9232            Tender
# 15919     E-Purchasing
# 3688            Tender
# 10519           Tender
# 10515           Tender
# 9237            Tender
# 10526           Tender
# 9221            Tender

# %% [markdown]
# ## 📊 Distribusi Metode & Jenis Pengadaan

# %%
metode_counts = df['metode_pengadaan'].value_counts()
jenis_counts = df['jenis_pengadaan'].value_counts()
print('Metode pengadaan (top 5):')
print(metode_counts.head())
print('Jenis pengadaan (top 5):')
print(jenis_counts.head())

fig, axes = plt.subplots(1, 2, figsize=(14, 5))
metode_counts.plot(kind='bar', ax=axes[0], color='#1f77b4')
axes[0].set_title('Jumlah Paket per Metode')
axes[0].set_xlabel('Metode Pengadaan')
axes[0].set_ylabel('Jumlah Paket')
axes[0].tick_params(axis='x', rotation=45)

jenis_counts.plot(kind='barh', ax=axes[1], color='#ff7f0e')
axes[1].set_title('Jumlah Paket per Jenis')
axes[1].set_xlabel('Jumlah Paket')
plt.tight_layout()
plt.show()
# Out:
# Metode pengadaan (top 5):
# metode_pengadaan
# E-Purchasing           11245
# Pengadaan Langsung      4515
# Dikecualikan             497
# Tender                    77
# Penunjukan Langsung       48
# Name: count, dtype: int64
# Jenis pengadaan (top 5):
# jenis_pengadaan
# Barang                  10530
# Pekerjaan Konstruksi     2905
# Jasa Lainnya             1678
# Jasa Konsultansi         1315
# Barang;Barang               1
# Name: count, dtype: int64

# %% [markdown]
# ## 🏛️ Analisis K/L/PD

# %%
top_klpd_count = df['nama_klpd'].value_counts().head(10)
top_klpd_pagu = (
    df.groupby('nama_klpd')['pagu']
    .sum()
    .sort_values(ascending=False)
    .head(10)
)
print('Top 10 K/L/PD berdasarkan jumlah paket:')
print(top_klpd_count)
print('Top 10 K/L/PD berdasarkan total pagu (Rp):')
print(top_klpd_pagu)
# Out:
# Top 10 K/L/PD berdasarkan jumlah paket:
# nama_klpd
# Provinsi Kalimantan Barat    16430
# Name: count, dtype: int64
# Top 10 K/L/PD berdasarkan total pagu (Rp):
# nama_klpd
# Provinsi Kalimantan Barat    2111666072118
# Name: pagu, dtype: int64

# %%
fig, axes = plt.subplots(1, 2, figsize=(16, 5))
top_klpd_count.plot(kind='barh', ax=axes[0], color='#2ca02c')
axes[0].set_title('Top 10 K/L/PD (Jumlah Paket)')
axes[0].set_xlabel('Jumlah Paket')
axes[0].invert_yaxis()

(top_klpd_pagu / 1_000_000_000).plot(kind='barh', ax=axes[1], color='#d62728')
axes[1].set_title('Top 10 K/L/PD (Total Pagu, Miliar)')
axes[1].set_xlabel('Total Pagu (Miliar)')
axes[1].invert_yaxis()

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 🇮🇩 Status PDN, UKM, dan PRADIPA

# %%
pdn_dist = df['status_pdn'].value_counts()
ukm_dist = df['status_ukm'].value_counts()
pradipa_dist = df['status_pradipa'].value_counts()

print(f"Persentase PDN: {(pdn_dist.get('Ya', 0) / len(df) * 100):.2f}%")
print(f"Persentase UKM: {(ukm_dist.get('Ya', 0) / len(df) * 100):.2f}%")
print(f"Persentase PRADIPA: {(pradipa_dist.get('Ya', 0) / len(df) * 100):.2f}%")

fig, axes = plt.subplots(1, 3, figsize=(15, 5))
pdn_dist.plot(kind='pie', autopct='%1.1f%%', ax=axes[0], title='Status PDN')
axes[0].set_ylabel('')
ukm_dist.plot(kind='pie', autopct='%1.1f%%', ax=axes[1], title='Status UKM')
axes[1].set_ylabel('')
pradipa_dist.plot(kind='pie', autopct='%1.1f%%', ax=axes[2], title='Status PRADIPA')
axes[2].set_ylabel('')
plt.tight_layout()
plt.show()
# Out:
# Persentase PDN: 0.00%
# Persentase UKM: 0.00%
# Persentase PRADIPA: 0.00%

# %% [markdown]
# ## 🕵️ Deteksi Missing Values

# %%
missing = df.isnull().sum()
missing_pct = (missing / len(df)) * 100
missing_df = (
    pd.DataFrame({'Missing': missing, 'Percentage': missing_pct})
    .sort_values('Missing', ascending=False)
)
missing_df[missing_df['Missing'] > 0]
# Out:
#                         Missing  Percentage
# kode_rup_tahun_pertama    16430      100.00
# nomor_kontrak             16430      100.00
# tahun_pertama             16430      100.00
# kd_rup_lokal              16430      100.00
# kd_rup_swakelola          16416       99.91
# alasan_non_ukm            16362       99.59
# alasan_dikecualikan       16112       98.06
# nip_ppk                      39        0.24
# username_ppk                 39        0.24
# nama_ppk                     39        0.24
# kd_jenis_pengadaan            1        0.01
# jenis_pengadaan               1        0.01

# %%
missing_pct[missing_pct > 0].plot(kind='barh', figsize=(8, 6), color='#9467bd')
plt.title('Persentase Missing Values per Kolom')
plt.xlabel('Percentage (%)')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 🛠️ Penanganan Missing Values

# %%
df_dropna = df.dropna(subset=['pagu', 'metode_pengadaan'])
df_fillna = df.fillna({'pagu': 0, 'metode_pengadaan': 'Unknown'})
print(f"Baris setelah drop subset: {len(df_dropna):,}")
print(f"Baris setelah fill default: {len(df_fillna):,}")
# Out:
# Baris setelah drop subset: 16,430
# Baris setelah fill default: 16,430

# %% [markdown]
# ## 🔤 Operasi String

# %%
df['nama_paket_upper'] = df['nama_paket'].str.upper()
df['nama_paket_lower'] = df['nama_paket'].str.lower()
df['nama_paket_length'] = df['nama_paket'].str.len()
df['nama_paket_clean'] = df['nama_paket'].str.replace('/', '-', regex=False)
konstruksi_packages = df[df['nama_paket'].str.contains('Konstruksi', case=False, na=False)]

string_preview = df[['nama_paket', 'nama_paket_upper', 'nama_paket_length']].head()
string_preview
# Out:
#                                           nama_paket  \
# 0           Belanja Bahan Makanan dan Minuman Pasien
# 1  Perencanaan Rehabilitasi Gedung UPT Pengujian ...
# 2  PENGAWASAN TEKNIS PENGGANTIAN/PEMBANGUNAN JEMB...
# 3  PENGAWASAN TEKNIS PENINGKATAN JALAN TANJUNG  M...
# 4  PENGAWASAN TEKNIS PENINGKATAN JALAN MARAU  AIR...
#
#                                     nama_paket_upper  nama_paket_length
# 0           BELANJA BAHAN MAKANAN DAN MINUMAN PASIEN                 40
# 1  PERENCANAAN REHABILITASI GEDUNG UPT PENGUJIAN ...                 73
# 2  PENGAWASAN TEKNIS PENGGANTIAN/PEMBANGUNAN JEMB...                 79
# 3  PENGAWASAN TEKNIS PENINGKATAN JALAN TANJUNG  M...                 62
# 4  PENGAWASAN TEKNIS PENINGKATAN JALAN MARAU  AIR...                 51

# %% [markdown]
# ## 🗓️ Operasi DateTime

# %%
df['tgl_pengumuman_paket'] = pd.to_datetime(df['tgl_pengumuman_paket'], errors='coerce')
df['tahun_pengumuman'] = df['tgl_pengumuman_paket'].dt.year
df['bulan_pengumuman'] = df['tgl_pengumuman_paket'].dt.month_name()
df['hari_pengumuman'] = df['tgl_pengumuman_paket'].dt.day

mask_q1 = (
    (df['tgl_pengumuman_paket'] >= '2025-01-01') &
    (df['tgl_pengumuman_paket'] <= '2025-03-31')
)
q1_data = df.loc[mask_q1]
print(f"Jumlah paket Q1 2025: {len(q1_data):,}")
df[['tgl_pengumuman_paket', 'tahun_pengumuman', 'bulan_pengumuman']].head()
# Out:
# Jumlah paket Q1 2025: 8,644
#   tgl_pengumuman_paket  tahun_pengumuman bulan_pengumuman
# 0  2024-11-22 22:22:47              2024         November
# 1  2024-12-09 15:52:13              2024         December
# 2  2024-12-16 14:25:38              2024         December
# 3  2024-12-12 17:05:24              2024         December
# 4  2024-12-12 17:05:24              2024         December

# %% [markdown]
# ## 📈 Statistik Pagu

# %%
print(f"Mean:   Rp {df['pagu'].mean():,.2f}")
print(f"Median: Rp {df['pagu'].median():,.2f}")
print(f"Std:    Rp {df['pagu'].std():,.2f}")
print(f"Min:    Rp {df['pagu'].min():,.2f}")
print(f"Max:    Rp {df['pagu'].max():,.2f}")
# Out:
# Mean:   Rp 128,525,019.61
# Median: Rp 8,354,500.00
# Std:    Rp 1,217,381,191.99
# Min:    Rp 1.00
# Max:    Rp 74,802,424,962.00

# %%
q1 = df['pagu'].quantile(0.25)
q2 = df['pagu'].quantile(0.50)
q3 = df['pagu'].quantile(0.75)
iqr = q3 - q1
print(f"Q1 (25%): Rp {q1:,.2f}")
print(f"Q2 (50%): Rp {q2:,.2f}")
print(f"Q3 (75%): Rp {q3:,.2f}")
print(f"IQR:       Rp {iqr:,.2f}")
# Out:
# Q1 (25%): Rp 1,360,000.00
# Q2 (50%): Rp 8,354,500.00
# Q3 (75%): Rp 91,734,075.00
# IQR:       Rp 90,374,075.00

# %% [markdown]
# ## 🚨 Deteksi Outlier dengan IQR

# %%
lower_bound = q1 - 1.5 * iqr
upper_bound = q3 + 1.5 * iqr
outliers = df[(df['pagu'] < lower_bound) | (df['pagu'] > upper_bound)]
print(f"Jumlah outlier: {len(outliers):,}")
print(f"Persentase outlier: {len(outliers) / len(df) * 100:.2f}%")
df_no_outliers = df[(df['pagu'] >= lower_bound) & (df['pagu'] <= upper_bound)]
# Out:
# Jumlah outlier: 621
# Persentase outlier: 3.78%

# %% [markdown]
# ## 🔗 Analisis Korelasi

# %%
numeric_cols = df.select_dtypes(include=[np.number]).columns
dcorr = df[numeric_cols].corr()
pagu_corr = dcorr['pagu'].sort_values(ascending=False)
print(pagu_corr)

plt.figure(figsize=(10, 8))
sns.heatmap(dcorr, cmap='coolwarm', center=0)
plt.title('Correlation Matrix')
plt.tight_layout()
plt.show()
# Out:
# pagu                   1.00
# kd_metode_pengadaan    0.10
# kd_rup                 0.05
# hari_pengumuman        0.04
# kd_satker              0.02
# nama_paket_length     -0.00
# tahun_pengumuman      -0.01
# kd_rup_swakelola      -0.35
# tahun_anggaran          NaN
# Name: pagu, dtype: float64

# %% [markdown]
# ## 📉 Tren Pengumuman Paket

# %%
df_dates = df.dropna(subset=['tgl_pengumuman_paket']).set_index('tgl_pengumuman_paket')
daily_counts = df_dates.resample('D').size()
monthly_counts = df_dates.resample('M').size()

fig, axes = plt.subplots(2, 1, figsize=(12, 8), sharex=False)
daily_counts.plot(ax=axes[0], title='Pengumuman Paket per Hari')
axes[0].set_ylabel('Jumlah Paket')
axes[0].grid(True, alpha=0.3)

monthly_counts.plot(ax=axes[1], marker='o', title='Pengumuman Paket per Bulan')
axes[1].set_ylabel('Jumlah Paket')
axes[1].grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 📊 Visualisasi Distribusi Pagu

# %%
plt.figure(figsize=(10, 5))
df['pagu'].plot(kind='hist', bins=50, edgecolor='black', alpha=0.7)
plt.axvline(df['pagu'].mean(), color='red', linestyle='--', label='Mean')
plt.axvline(df['pagu'].median(), color='green', linestyle='--', label='Median')
plt.title('Distribusi Pagu Pengadaan')
plt.xlabel('Pagu (Rupiah)')
plt.ylabel('Frekuensi')
plt.legend()
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 🍰 Pie Chart Metode Pengadaan

# %%
metode_counts = df['metode_pengadaan'].value_counts()
plt.figure(figsize=(8, 8))
metode_counts.plot(kind='pie', autopct='%1.1f%%', explode=[0.05] + [0]*(len(metode_counts)-1))
plt.ylabel('')
plt.title('Proporsi Metode Pengadaan')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 🎨 Mini Dashboard (Subplots)

# %%
fig, axes = plt.subplots(2, 2, figsize=(15, 10))
df['pagu'].plot(kind='hist', bins=40, edgecolor='black', ax=axes[0, 0], title='Distribusi Pagu')
df['metode_pengadaan'].value_counts().plot(kind='bar', ax=axes[0, 1], title='Metode Pengadaan')
df['jenis_pengadaan'].value_counts().plot(kind='barh', ax=axes[1, 0], title='Jenis Pengadaan')
df.boxplot(column='pagu', by='metode_pengadaan', ax=axes[1, 1])
axes[1, 1].set_title('Boxplot Pagu vs Metode')
plt.suptitle('')
plt.tight_layout()
plt.show()

# %% [markdown]
# ## ✅ Summary & Insight
#
# - Data mencakup lebih dari 16 ribu paket pengadaan dengan nilai total triliunan rupiah.
# - Metode Tender mendominasi baik dari sisi jumlah paket maupun total pagu.
# - Distribusi pagu sangat skewed sehingga perlu melihat median dan IQR.
# - Beberapa kolom memiliki missing values sehingga perlu strategi drop/fill sebelum analisis lanjutan.
# - Konversi kolom tanggal membuka peluang analisis tren harian/bulanan.

# %% [markdown]
# ## 🧪 Latihan Mandiri
#
# 1. Hitung mean, median, dan standar deviasi pagu setelah menghapus outlier, lalu bandingkan dengan nilai awal.
# 2. Identifikasi top 10 satker berdasarkan jumlah paket (bukan pagu) dan buat bar chart perbandingannya.
# 3. Buat ringkasan rata-rata pagu per metode pengadaan dan tampilkan sebagai horizontal bar chart.
# 4. Analisis tren bulanan: hitung pertumbuhan month-over-month dari `monthly_counts`.
# 5. Lakukan data quality check tambahan: hitung duplikat berdasarkan `kd_rup` dan hapus jika perlu.
# 6. Buat filter custom (misal paket konstruksi dengan pagu > 1M) dan rangkum insight-nya.

# %% [markdown]
# ## 🔜 Next Steps
#
# - Lanjutkan ke `day1/session2_duckdb` untuk mempelajari SQL analitik dengan DuckDB.
# - Gunakan hasil eksplorasi ini sebagai dasar pembuatan dashboard (misal Streamlit di Hari 5).
# - Simpan hasil pembersihan data (`df_no_outliers`, `df_dropna`, dll.) jika ingin digunakan kembali.
